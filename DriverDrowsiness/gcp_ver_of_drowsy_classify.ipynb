# %%
# install necessary package
# !pip install tensorflow_addons
# Out:
# Collecting tensorflow_addons
#   Downloading tensorflow_addons-0.23.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (611 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 611.8/611.8 kB 11.5 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow_addons) (23.2)
# Collecting typeguard<3.0.0,>=2.7 (from tensorflow_addons)
#   Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Installing collected packages: typeguard, tensorflow_addons
# Successfully installed tensorflow_addons-0.23.0 typeguard-2.13.3

# %%
import os
import pandas as pd
import numpy as np
import random
from PIL import Image
import matplotlib.pyplot as plt
import tensorflow as tf
import tensorflow_addons as tfa
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from tensorflow.keras.callbacks import EarlyStopping
from keras import models
from keras import layers
import seaborn as sns
import matplotlib.pyplot as plt

random.seed(2)
# %matplotlib inline
# Out:
# /usr/local/lib/python3.10/dist-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(

# %%
#1. Mount Drive
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
gdrive = "/content/gdrive/MyDrive/207_project_files"
#KP: You'll see a pop-up from google to sign-in and connect to your drive
# Out:
# Mounted at /content/gdrive

# %%
#2. Copy archive.zip to gdrive to /home
#gdrive = "/content/gdrive/MyDrive"
# !cp $gdrive/archive.zip /home

# %%
# !rm -rf /home/data

# %%
#3. Unzip archive.zip to /home/data/full
# !mkdir -p /home/data/full
# !unzip /home/archive.zip -d /home/data/full/ > /dev/null

# %%
# !mv /home/data/full/Driver\ Drowsiness\ Dataset\ \(DDD\) /home/data/train

# !mv /home/data/train/Non\ Drowsy  /home/data/train/NonDrowsy

# %%
# !ls /home/data/train/Drowsy | tail
# Out:
# ZC1349.png
# ZC1350.png
# ZC1351.png
# ZC1352.png
# ZC1353.png
# ZC1354.png
# ZC1355.png
# ZC1356.png
# ZC1357.png
# ZC1358.png

# %%
# !ls /home/data/train/NonDrowsy | tail
# Out:
# zc1697.png
# zc1698.png
# zc1699.png
# zc1700.png
# zc1702.png
# zc1703.png
# zc1704.png
# zc1705.png
# zc1706.png
# zc1707.png

# %%
# Randomize file_names in train dataset

import os
import csv
import random
import string

def randomize_file_names (dir_path, mapping_file_name):


  # create a list of all the files in the directory
  files = os.listdir(dir_path)

  # create a dictionary to store the old and new file names
  file_mapping = {}

  # loop through each file in the directory
  for file in files:
      # generate a random string of 10 characters
      new_name = ''.join(random.choices(string.ascii_uppercase + string.digits, k=10))
      # get the file extension
      ext = os.path.splitext(file)[1]
      # create the new file name with the random string and the original file extension
      new_file_name = new_name + ext
      # rename the file
      os.rename(os.path.join(dir_path, file), os.path.join(dir_path, new_file_name))
      # add the old and new file names to the dictionary
      file_mapping[file] = new_file_name

  # write the file mapping to a csv file
  with open(mapping_file_name, 'w', newline='') as csvfile:
      writer = csv.writer(csvfile)
      writer.writerow(['Old Name', 'New Name'])
      for key, value in file_mapping.items():
          writer.writerow([key, value])

randomize_file_names ("/home/data/train/NonDrowsy/", 'file_mapping_NonDrowsy.csv')
randomize_file_names ("/home/data/train/Drowsy/", 'file_mapping_Drowsy.csv')

# %%
# Dump old test folder and recreate it
# !rm -rf /home/data/test/Drowsy
# !rm -rf /home/data/test/NonDrowsy

# !mkdir -p /home/data/test/Drowsy
# !mkdir -p /home/data/test/NonDrowsy

# %%
# Train and Test split on original dataset (not being used any more now)
# import os
# import random
# import shutil

# def split_test(percent, src_dir, dst_dir):

#   # get a list of all the image files in the source directory
#   image_files = [f for f in os.listdir(src_dir) if f.endswith('.jpg') or f.endswith('.png')]

#   # calculate the number of images to move
#   num_images_to_move = int(len(image_files) * percent)

#   # randomly select the images to move
#   images_to_move = random.sample(image_files, num_images_to_move)

#   # move the selected images to the destination directory
#   for image in images_to_move:
#       src_path = os.path.join(src_dir, image)
#       dst_path = os.path.join(dst_dir, image)
#       shutil.move(src_path, dst_path)

# split_test(0.3, '/home/data/train/Drowsy', '/home/data/test/Drowsy')
# split_test(0.3, '/home/data/train/NonDrowsy', '/home/data/test/NonDrowsy')

# %%
# # Verify sample Drowsy files  (not in use anymore)
# !ls /home/data/test/Drowsy | tail

# %%
# # Verify sample NonDrowsy files (not in use anymore)
# !ls /home/data/test/NonDrowsy | tail

# %%
# Remove old manual_annotate folders if exist
# !rm -rf /home/data/manual_annotate/

# !cp -r $gdrive/data_sample/manual_annotate/  /home/data/manual_annotate/

# %%
# Verify sample Drowsy files in test
# !ls /home/data/manual_annotate/test/Drowsy | tail
# Out:
# ZC0003.png
# ZC0007.png
# ZC0038.png
# ZC0050.png
# ZC0059.png
# ZC0076.png
# ZC0081.png
# ZC0112.png
# ZC0128.png
# ZC0157.png

# %%
# Verify sample NonDrowsy files in test
# !ls /home/data/manual_annotate/test/NonDrowsy | tail
# Out:
# zc0001.png
# zc0013.png
# zc0031.png
# zc0042.png
# zc0103.png
# zc0199.png
# zc0251.png
# zc0334.png
# zc0801.png
# zc1040.png

# %%
# Verify sample Drowsy files in train
# !ls /home/data/manual_annotate/train/Drowsy | tail
# Out:
# R0010.png
# R0036.png
# R0076.png
# R0086.png
# R0091.png
# R0166.png
# R0168.png
# R0169.png
# R0171.png
# R0219.png

# %%
# Verify sample NonDrowsy files in train

# !ls /home/data/manual_annotate/train/NonDrowsy | tail
# Out:
# r0001.png
# r0014.png
# r0043.png
# r0068.png
# r0125.png
# r0169.png
# r0261.png
# r0303.png
# r0371.png
# r0522.png

# %%
# TBD: Add in option to switch between local and gcp instance run option
# Make use of base_variable and additional paths

# original_drowsy_dataset_dir = './data/original_dataset/Drowsy'
# original_nondrowsy_dataset_dir = './data/original_dataset/NonDrowsy'

original_drowsy_dataset_dir = '/home/data/train/Drowsy'
original_nondrowsy_dataset_dir = '/home/data/train/NonDrowsy'


# manual_annotation_train_drowsy_dir = './data/manual_annotate/train/Drowsy'
# manual_annotation_train_nondrowsy_dir = './data/manual_annotate/train/NonDrowsy'

manual_annotation_train_drowsy_dir = '/home/data/manual_annotate/train/Drowsy'
manual_annotation_train_nondrowsy_dir = '/home/data/manual_annotate/train/NonDrowsy'


# manual_annotation_test_drowsy_dir = './data/manual_annotate/test/Drowsy'
# manual_annotation_test_nondrowsy_dir = './data/manual_annotate/test/NonDrowsy'

manual_annotation_test_drowsy_dir = '/home/data/manual_annotate/test/Drowsy'
manual_annotation_test_nondrowsy_dir = '/home/data/manual_annotate/test/NonDrowsy'



# manual_annotation_nondrowsy_dir = './data/manual_annotate/NonDrowsy'
# train_dir = './data/manual_annotate/train80'

manual_annotation_nondrowsy_dir = '/home/data/manual_annotate/NonDrowsy'
train_dir = '/home/data/manual_annotate/train80'

# %% [markdown]
# #### Dataset
#
# The Driver Drowsiness Dataset (DDD) (https://www.kaggle.com/datasets/ismailnasri20/driver-drowsiness-dataset-ddd/) is an extracted and cropped faces of drivers from the videos of the Real-Life Drowsiness Dataset. The frames were extracted from videos as images using VLC software. After that, the Viola-Jones algorithm has been used to extract the region of interest from captured images. The dataset on Kaggle has following properties
#
# The dataset has the following properties :
# • RGB images
# • 2 classes (Drowsy & Non Drowsy)
# • Size of image : 227 x 227
# • More than 41,790 images in total

# %%
def get_file_count(folder_path):
    # Get the list of files in the folder
    files = os.listdir(folder_path)

    # Count the number of files
    file_count = len(files)

    return file_count

# Get the file counts
drowsy_count = get_file_count(original_drowsy_dataset_dir)
non_drowsy_count = get_file_count(original_nondrowsy_dataset_dir)

# Create a dataframe
df = pd.DataFrame({'Category': ['Drowsy', 'Non Drowsy'], 'Count': [drowsy_count, non_drowsy_count]})

# Display the dataframe
display(df)
# Out:
#      Category  Count
# 0      Drowsy  22348
# 1  Non Drowsy  19445

# %% [markdown]
# Drowsy folder contains around 22348 files and Non Drowsy folder contains around 19445 files. Upon further analysis it was found that there were multiple images of same person increasing the count in dataset. Also, the data set seemed to have incorrect labeling. Lot of images that seemed Non Drowsy were labeled as Drowsy.
#
# Hence, a concious decision was taken to manually label 10 images of each person that distinctly categorized image as drowsy and Non Drowsy.

# %%
# Get the file counts
train_drowsy_count = get_file_count(manual_annotation_train_drowsy_dir)
train_non_drowsy_count = get_file_count(manual_annotation_train_nondrowsy_dir)

test_drosy_count = get_file_count(manual_annotation_test_drowsy_dir)
test_nondrowsy_count = get_file_count(manual_annotation_test_nondrowsy_dir)

total_drowsy_count = train_drowsy_count + test_drosy_count
total_non_drowsy_count = train_non_drowsy_count + test_nondrowsy_count

# Create a dataframe
df = pd.DataFrame({'Category': ['Drowsy', 'Non Drowsy'], 'Count': [total_drowsy_count, total_non_drowsy_count]})

# Display the dataframe
display(df)
# Out:
#      Category  Count
# 0      Drowsy    276
# 1  Non Drowsy    234

# %% [markdown]
# A comprehensive dataset comprising 510 images underwent manual annotation. These images are designated for training, validation, and testing purposes. They are to be divided into respective subsets for training, validation, and testing, adhering to a proportional allocation of 60%, 20%, and 20%. Given the nature of the labeling process, which involved approximately 10 images per individual, there exists a potential overlap wherein the test subset might include images of individuals previously encountered during the model's training phase. To address this and to assess the model's performance with previously unseen data, a distinct set of images, specifically those featuring individuals whose names commence with letters S through Z, has been segregated. This measure is intended to evaluate the model's generalization capabilities on novel data.

# %% [markdown]
# #### Drowsy Annotated Images

# %%
def plot_images(directory, title):

    # Get the list of image files in the directory
    image_files = os.listdir(directory)

    # Create a figure with a grid of 1x4 subplots
    fig, axs = plt.subplots(1, 4, figsize=(12, 3))

    # Loop through the first 4 image files
    for i in range(4):
        # Get the image file path
        image_file = os.path.join(directory, image_files[i])

        # Open the image using PIL
        image = Image.open(image_file)

        # Display the image in the corresponding subplot
        axs[i].imshow(image)
        axs[i].axis('on')

        # Display the label above the image
        axs[i].set_title(title, fontsize=10, pad=2)

        # Add grid lines to the subplot
        axs[i].grid(True)

    # Show the figure
    plt.show()

# %%
# Set the directory path
plot_images(directory = manual_annotation_train_drowsy_dir, title = 'Drowsy')

# %% [markdown]
# #### Non Drowsy Annotated Images

# %%
plot_images(directory = manual_annotation_train_nondrowsy_dir, title = 'Non Drowsy')

# %% [markdown]
# #### Preprocessing
# The preprocessing of the image dataset will be executed through a two-stage process. Initially, the first stage will involve the random selection of 150 images each from directories labeled 'Drowsy' and 'NonDrowsy'. Selecting equal images would balance our dataset. In this phase, images from the 'Drowsy' directory will be annotated with a label of 1, while those from the 'NonDrowsy' directory will receive a label of 0, thus facilitating binary classification.
#
# Subsequently, the second stage of preprocessing will focus on standardizing the dimensions of the images to a uniform size of 80x80 pixels. The data is split in training, validation and test set in this step. Additionally, this stage will incorporate various image augmentation techniques, including the adjustment of brightness and contrast, as well as the horizontal flipping of images. These augmented images will then be systematically incorporated into the training dataset, thereby enriching it and potentially enhancing the robustness of the model by exposing it to a more diverse range of data variations.

# %%
def data_preprocess_step1(train_dir, num_images=150):
    # create empty lists to store the images and their labels
    images = []
    labels = []

    # loop through each subdirectory
    for subdir in os.listdir(train_dir):
        path = os.path.join(train_dir, subdir)
        print(path)
        if os.path.isdir(path):

            # get a list of all the image files in the subdirectory
            image_files = os.listdir(path)

            # randomly select num_images images from the list
            selected_images = random.sample(image_files, num_images)

            # loop through the selected images
            for image_file in selected_images:
                # load the image using load_img
                img = load_img(os.path.join(path, image_file), target_size=(80, 80))

                # convert the image to an array using img_to_array
                img_array = img_to_array(img)

                # append the image and its label to the lists
                images.append(img_array)

                if subdir == "Drowsy":
                    labels.append(1)
                else:
                    labels.append(0)

    # convert the images and labels to numpy arrays
    images = np.stack(images)
    labels = np.array(labels).flatten()
    return images, labels

# %%
def preprocess_data_step2(images, y, split=(0.6,0.2,0.2), IMAGE_SIZE=(80,80), CONTRAST_FACTOR=3, DELTA=0.3, normalize=True):

    ### create train/validation/test sets ###
    #########################################
    # NOTE: Each time you run this cell, you'll re-shuffle the data. The ordering will be the same due to the random seed generator
    tf.random.set_seed(1235)
    np.random.seed(1235)
    shuffle = np.random.permutation(np.arange(images.shape[0]))
    images, y = images[shuffle], y[shuffle]

    splits = np.multiply(len(images), split).astype(int)
    X_train, X_val, X_test = np.split(images, [splits[0], splits[0]+splits[1]])
    y_train, y_val, y_test = np.split(y, [splits[0], splits[0]+splits[1]])

    ### image transformation on training, validation, and test data ###
    ###################################################################
    # image resize
    X_train = tf.image.resize(X_train, size=IMAGE_SIZE)
    X_val = tf.image.resize(X_val, size=IMAGE_SIZE)
    X_test = tf.image.resize(X_test, size=IMAGE_SIZE)

    # rescale image to [0,1], i.e., greyscale
    if normalize:
        X_train = X_train/255.0
        X_val = X_val/255.0
        X_test = X_test/255.0

    ### image augmentation on training data ###
    ###########################################
    # adjust brightness
    X_train_augm = tf.image.adjust_brightness(X_train, delta=DELTA)

    # adjust contrast
    X_train_augm = tf.image.adjust_contrast(X_train_augm, contrast_factor=CONTRAST_FACTOR)

    # random flip
    X_train_augm = tf.image.random_flip_left_right(X_train_augm)

    X_train_augm = tfa.image.rotate(X_train_augm, np.random.uniform(-30, 30))

    # concatenate original X_train and augmented X_train data
    X_train = tf.concat([X_train, X_train_augm],axis=0)

    # concatenate y_train (note the label is preserved)
    y_train_augm = y_train
    y_train = tf.concat([y_train, y_train_augm],axis=0)

    # shuffle X_train and y_train, i.e., shuffle two tensors in the same order
    shuffle = tf.random.shuffle(tf.range(tf.shape(X_train)[0], dtype=tf.int32))
    X_train = tf.gather(X_train, shuffle)
    y_train = tf.gather(y_train, shuffle).numpy() #also transforms y_train to numpy array

    return X_train, y_train, X_val, y_val, X_test, y_test

# %%
def preprocess(train_dir, normalize=True):
    # Preprocess step 1: Randomly select 150 images from
    # the train directory and convert them to arrays
    images, y = data_preprocess_step1(train_dir, num_images=150)

    # Preprocess step 2: Split the data into training, validation, and test sets
    X_train, y_train, X_val, y_val, X_test, y_test = preprocess_data_step2(
        images, y, split=(0.79,0.2,0.1), IMAGE_SIZE=(80,80), CONTRAST_FACTOR=3, DELTA=0.3, normalize=normalize)

    print('\n----------Preprocessing Summary----------')
    print(f"images shape {images.shape}")
    print(f"y shape {y.shape}")
    print(f"X_train shape {X_train.shape}")
    print(f"y_train shape {y_train.shape}")
    print(f"X_val shape {X_val.shape}")
    print(f"y_val shape {y_val.shape}")
    print(f"X_test shape {X_test.shape}")
    print(f"y_test shape {y_test.shape}")
    print

    return X_train, y_train, X_val, y_val, X_test, y_test

# %% [markdown]
# #### Model
# Describe model here

# %%
def build_modelV2():
    tf.keras.backend.clear_session()

    model = tf.keras.Sequential()

    # add first convolution layer to the model
    model.add(tf.keras.layers.Conv2D(
        filters=16,
        kernel_size=(5, 5),
        strides=(1, 1),
        padding='same',
        data_format='channels_last',
        name='conv_1'))

    # Add Batch Normalization layer
    model.add(tf.keras.layers.BatchNormalization())

    # Add the activation layer separately
    model.add(tf.keras.layers.Activation('relu'))

    model.add(tf.keras.layers.Dropout(
        rate=0.3))


    # add a max pooling layer with pool size (2,2) and strides of 2
    # (this will reduce the spatial dimensions by half)
    model.add(tf.keras.layers.MaxPool2D(
        pool_size=(2, 2),
        name='pool_1'))


    # add second convolutional layer
    model.add(tf.keras.layers.Conv2D(
        filters=16,
        kernel_size=(5, 5),
        strides=(1, 1),
        padding='same',
        name='conv_2'))

    # Add Batch Normalization layer
    model.add(tf.keras.layers.BatchNormalization())

    # Add the activation layer separately
    model.add(tf.keras.layers.Activation('relu'))


    # add second max pooling layer with pool size (2,2) and strides of 2
    # (this will further reduce the spatial dimensions by half)
    model.add(tf.keras.layers.MaxPool2D(
        pool_size=(2, 2), name='pool_2')
    )

    model.add(tf.keras.layers.Dropout(
        rate=0.5))


    # add a fully connected layer (need to flatten the output of the previous layers first)
    model.add(tf.keras.layers.Flatten())
    model.add(tf.keras.layers.Dense(
        units=128,
        name='fc_1',
        activation='relu'))

    # add dropout layer
    model.add(tf.keras.layers.Dropout(
        rate=0.5))

    model.add(tf.keras.layers.Dense(
        units=64,
        name='fc_2'
    ))

    model.add(tf.keras.layers.BatchNormalization())

    model.add(tf.keras.layers.Activation('relu'))

    model.add(tf.keras.layers.Dense(
        units=32,
        name='fc_3'
        ))

    model.add(tf.keras.layers.BatchNormalization())

    model.add(tf.keras.layers.Activation('relu'))

    # add the last fully connected layer
    # this last layer sets the activation function to "None" in order to output the logits
    # note that passing activation = "sigmoid" will return class memembership probabilities but
    # in TensorFlow logits are prefered for numerical stability
    # set units=1 to get a single output unit (remember it's a binary classification problem)
    model.add(tf.keras.layers.Dense(
        units=1,
        name='fc_4',
        activation=None))

    # build model and print summary
    tf.random.set_seed(1)
    model.build(input_shape=(None, 80, 80, 3))


    return model

# %%
def build_model(learning_rate=0.001):

    model = build_modelV2()
    model.summary()
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),
                loss=tf.keras.losses.BinaryCrossentropy(from_logits=True), #set from_ligits=True because our last layer does not apply sigmoid
                metrics=['accuracy'])
    return model

# %% [markdown]
# #### Baseline Accuracy

# %%
def test_baseline_accuracy(model, test_dir, IMAGE_SIZE=(80,80)):
    tf.random.set_seed(1235)
    np.random.seed(1235)

    image_test, label_test = data_preprocess_step1(test_dir, num_images=50)

    shuffle = np.random.permutation(np.arange(image_test.shape[0]))
    image_test, label_test = image_test[shuffle], label_test[shuffle]
    shuffle = np.random.permutation(np.arange(image_test.shape[0]))
    image_test, label_test = image_test[shuffle], label_test[shuffle]

    image_test = tf.image.resize(image_test, size=IMAGE_SIZE)

    image_test = image_test/255.0

    test_results = model.evaluate(image_test, label_test)

    print('\n----------Baseline Model Test Results----------')
    print('\nBaseline Test Acc. {:.2f}%'.format(test_results[1]*100))
    print('-----------------------------------------------')

# %%
def fit_model(model, X_train, y_train, X_val, y_val, epochs=20):
    tf.random.set_seed(6666)
    np.random.seed(6666)

    # Define the EarlyStopping callback
    early_stopping = EarlyStopping(patience=10, restore_best_weights=True)

    history = model.fit(X_train, y_train,
                        epochs=epochs,
                        validation_data=(X_val, y_val)
                        #callbacks=[early_stopping]
    )

    return history

# %%
def plot_history(history):
    hist = history.history
    x_arr = np.arange(len(hist['loss'])) + 1

    fig = plt.figure(figsize=(12, 4))
    ax = fig.add_subplot(1, 2, 1)
    ax.plot(x_arr, hist['loss'], '-o', label='Train loss')
    ax.plot(x_arr, hist['val_loss'], '--<', label='Validation loss')
    ax.legend(fontsize=15)
    ax.set_xlabel('Epoch', size=15)
    ax.set_ylabel('Loss', size=15)

    ax = fig.add_subplot(1, 2, 2)
    ax.plot(x_arr, hist['accuracy'], '-o', label='Train acc.')
    ax.plot(x_arr, hist['val_accuracy'], '--<', label='Validation acc.')
    ax.legend(fontsize=15)
    ax.set_xlabel('Epoch', size=15)
    ax.set_ylabel('Accuracy', size=15)
    plt.show()

# %%
def evaluate_model(model, test_dir):

    tf.random.set_seed(1235)
    np.random.seed(1235)

    IMAGE_SIZE=(80,80)

    image_test, label_test = data_preprocess_step1(test_dir + '/', num_images=50)

    shuffle = np.random.permutation(np.arange(image_test.shape[0]))
    image_test, label_test = image_test[shuffle], label_test[shuffle]

    image_test = tf.image.resize(image_test, size=IMAGE_SIZE)

    image_test = image_test/255.0

    test_results = model.evaluate(image_test, label_test)
    print('\n----------Model Test Accuracy Results----------')
    print('\nTest Acc. {:.2f}%'.format(test_results[1]*100))
    print('-----------------------------------------------')

    return test_results[1]*100

# %%
def preprocess_build_train_test(train_dir, test_dir, normalize=True, learning_rate=0.001, epochs=20):
    tf.keras.backend.clear_session()
    np.random.seed(0)
    tf.random.set_seed(0)
    X_train, y_train, X_val, y_val, X_test, y_test = preprocess(train_dir, normalize=normalize)
    model = build_model(learning_rate=learning_rate)
    test_baseline_accuracy(model, test_dir)
    history = fit_model(model, X_train, y_train, X_val, y_val, epochs=epochs)
    plot_history(history)
    test_acc = evaluate_model(model, test_dir)
    return model, test_acc

# %%
# rearrange to switch local paths
# model = preprocess_build_train_test('./data/manual_annotate/train', './data/manual_annotate/test', normalize=True)

model = preprocess_build_train_test('/home/data/manual_annotate/train', '/home/data/manual_annotate/test', normalize=True)
# Out:
# /home/data/manual_annotate/train/NonDrowsy
# /home/data/manual_annotate/train/Drowsy
#
# ----------Preprocessing Summary----------
# images shape (300, 80, 80, 3)
# y shape (300,)
# X_train shape (474, 80, 80, 3)
# y_train shape (474,)
# X_val shape (60, 80, 80, 3)
# y_val shape (60,)
# X_test shape (3, 80, 80, 3)
# y_test shape (3,)
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv_1 (Conv2D)             (None, 80, 80, 16)        1216
#
#  batch_normalization (Batch  (None, 80, 80, 16)        64
#  Normalization)
#
#  activation (Activation)     (None, 80, 80, 16)        0
#
#  dropout (Dropout)           (None, 80, 80, 16)        0
#
#  pool_1 (MaxPooling2D)       (None, 40, 40, 16)        0
#
#  conv_2 (Conv2D)             (None, 40, 40, 16)        6416
#
#  batch_normalization_1 (Bat  (None, 40, 40, 16)        64
#  chNormalization)
#
#  activation_1 (Activation)   (None, 40, 40, 16)        0
#
#  pool_2 (MaxPooling2D)       (None, 20, 20, 16)        0
#
#  dropout_1 (Dropout)         (None, 20, 20, 16)        0
#
#  flatten (Flatten)           (None, 6400)              0
#
#  fc_1 (Dense)                (None, 128)               819328
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  fc_2 (Dense)                (None, 64)                8256
#
#  batch_normalization_2 (Bat  (None, 64)                256
#  chNormalization)
#
#  activation_2 (Activation)   (None, 64)                0
#
#  fc_3 (Dense)                (None, 32)                2080
#
#  batch_normalization_3 (Bat  (None, 32)                128
#  chNormalization)
#
#  activation_3 (Activation)   (None, 32)                0
#
#  fc_4 (Dense)                (None, 1)                 33
#
# =================================================================
# Total params: 837841 (3.20 MB)
# Trainable params: 837585 (3.20 MB)
# Non-trainable params: 256 (1.00 KB)
# _________________________________________________________________
# /home/data/manual_annotate/test/NonDrowsy
# /home/data/manual_annotate/test/Drowsy
# 4/4 [==============================] - 8s 31ms/step - loss: 0.6932 - accuracy: 0.5000
#
# ----------Baseline Model Test Results----------
#
# Baseline Test Acc. 50.00%
# -----------------------------------------------
# Epoch 1/20
# 15/15 [==============================] - 7s 44ms/step - loss: 0.7397 - accuracy: 0.4958 - val_loss: 0.6987 - val_accuracy: 0.4833
# Epoch 2/20
# 15/15 [==============================] - 0s 15ms/step - loss: 0.6896 - accuracy: 0.5295 - val_loss: 0.6921 - val_accuracy: 0.4833
# Epoch 3/20
# 15/15 [==============================] - 0s 15ms/step - loss: 0.6780 - accuracy: 0.5422 - val_loss: 0.6948 - val_accuracy: 0.4833
# Epoch 4/20
# 15/15 [==============================] - 0s 14ms/step - loss: 0.6479 - accuracy: 0.5781 - val_loss: 0.6927 - val_accuracy: 0.4833
# Epoch 5/20
# 15/15 [==============================] - 0s 14ms/step - loss: 0.5931 - accuracy: 0.6371 - val_loss: 0.6874 - val_accuracy: 0.4833
# Epoch 6/20
# 15/15 [==============================] - 0s 14ms/step - loss: 0.5328 - accuracy: 0.6983 - val_loss: 0.6910 - val_accuracy: 0.4833
# Epoch 7/20
# 15/15 [==============================] - 0s 13ms/step - loss: 0.4754 - accuracy: 0.7468 - val_loss: 0.6818 - val_accuracy: 0.4833
# Epoch 8/20
# 15/15 [==============================] - 0s 14ms/step - loss: 0.3906 - accuracy: 0.8460 - val_loss: 0.6760 - val_accuracy: 0.4833
# Epoch 9/20
# 15/15 [==============================] - 0s 14ms/step - loss: 0.3169 - accuracy: 0.8650 - val_loss: 0.6646 - val_accuracy: 0.5000
# Epoch 10/20
# 15/15 [==============================] - 0s 13ms/step - loss: 0.2786 - accuracy: 0.8945 - val_loss: 0.6353 - val_accuracy: 0.5000
# Epoch 11/20
# 15/15 [==============================] - 0s 14ms/step - loss: 0.2311 - accuracy: 0.9072 - val_loss: 0.5563 - val_accuracy: 0.5833
# Epoch 12/20
# 15/15 [==============================] - 0s 14ms/step - loss: 0.2111 - accuracy: 0.9304 - val_loss: 0.5701 - val_accuracy: 0.5667
# Epoch 13/20
# 15/15 [==============================] - 0s 13ms/step - loss: 0.1976 - accuracy: 0.9388 - val_loss: 0.5028 - val_accuracy: 0.6667
# Epoch 14/20
# 15/15 [==============================] - 0s 14ms/step - loss: 0.1454 - accuracy: 0.9536 - val_loss: 0.3992 - val_accuracy: 0.7667
# Epoch 15/20
# 15/15 [==============================] - 0s 14ms/step - loss: 0.1718 - accuracy: 0.9367 - val_loss: 0.2966 - val_accuracy: 0.9000
# Epoch 16/20
# 15/15 [==============================] - 0s 14ms/step - loss: 0.1248 - accuracy: 0.9557 - val_loss: 0.2987 - val_accuracy: 0.9333
# Epoch 17/20
# 15/15 [==============================] - 0s 17ms/step - loss: 0.1353 - accuracy: 0.9578 - val_loss: 0.2019 - val_accuracy: 0.9500
# Epoch 18/20
# 15/15 [==============================] - 0s 18ms/step - loss: 0.1169 - accuracy: 0.9620 - val_loss: 0.2650 - val_accuracy: 0.8667
# Epoch 19/20
# 15/15 [==============================] - 0s 20ms/step - loss: 0.0938 - accuracy: 0.9747 - val_loss: 0.1943 - val_accuracy: 0.9000
# Epoch 20/20
# 15/15 [==============================] - 0s 18ms/step - loss: 0.0898 - accuracy: 0.9789 - val_loss: 0.1356 - val_accuracy: 0.9500
# /home/data/manual_annotate/test/NonDrowsy
# /home/data/manual_annotate/test/Drowsy
# 4/4 [==============================] - 0s 11ms/step - loss: 0.5264 - accuracy: 0.7500
#
# ----------Model Test Accuracy Results----------
#
# Test Acc. 75.00%
# -----------------------------------------------

# %% [markdown]
# #### Build train test 80x80 data

# %%
# not sure erroring here, creating this folder:
# !rm -rf '/home/data/manual_annotate/train80'
# !rm -rf '/home/data/manual_annotate/test80'


# !mkdir '/home/data/manual_annotate/train80'
# !mkdir '/home/data/manual_annotate/test80'

# Not sure if test and train folders are being copied, creating here:
# !cp -r '/home/data/manual_annotate/train' '/home/data/manual_annotate/train80'
# !cp -r '/home/data/manual_annotate/test' '/home/data/manual_annotate/test80'

# %%
test_acc = []
for _ in range(10):
    # model1, test_acc = preprocess_build_train_test('./data/manual_annotate/train80', './data/manual_annotate/test80', normalize=True, learning_rate=0.0001, epochs=40)
    model1, test_acc = preprocess_build_train_test('/home/data/manual_annotate/train80', '/home/data/manual_annotate/test80', normalize=True, learning_rate=0.0001, epochs=40)
print(test_acc)
# Out:
# /home/data/manual_annotate/train80/NonDrowsy
# /home/data/manual_annotate/train80/Drowsy
#
# ----------Preprocessing Summary----------
# images shape (300, 80, 80, 3)
# y shape (300,)
# X_train shape (474, 80, 80, 3)
# y_train shape (474,)
# X_val shape (60, 80, 80, 3)
# y_val shape (60,)
# X_test shape (3, 80, 80, 3)
# y_test shape (3,)
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv_1 (Conv2D)             (None, 80, 80, 16)        1216
#
#  batch_normalization (Batch  (None, 80, 80, 16)        64
#  Normalization)
#
#  activation (Activation)     (None, 80, 80, 16)        0
#
#  dropout (Dropout)           (None, 80, 80, 16)        0
#
#  pool_1 (MaxPooling2D)       (None, 40, 40, 16)        0
#
#  conv_2 (Conv2D)             (None, 40, 40, 16)        6416
#
#  batch_normalization_1 (Bat  (None, 40, 40, 16)        64
#  chNormalization)
#
#  activation_1 (Activation)   (None, 40, 40, 16)        0
#
#  pool_2 (MaxPooling2D)       (None, 20, 20, 16)        0
#
#  dropout_1 (Dropout)         (None, 20, 20, 16)        0
#
#  flatten (Flatten)           (None, 6400)              0
#
#  fc_1 (Dense)                (None, 128)               819328
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  fc_2 (Dense)                (None, 64)                8256
#
#  batch_normalization_2 (Bat  (None, 64)                256
#  chNormalization)
#
#  activation_2 (Activation)   (None, 64)                0
#
#  fc_3 (Dense)                (None, 32)                2080
#
#  batch_normalization_3 (Bat  (None, 32)                128
#  chNormalization)
#
#  activation_3 (Activation)   (None, 32)                0
#
#  fc_4 (Dense)                (None, 1)                 33
#
# =================================================================
# Total params: 837841 (3.20 MB)
# Trainable params: 837585 (3.20 MB)
# Non-trainable params: 256 (1.00 KB)
# _________________________________________________________________
# /home/data/manual_annotate/test80/NonDrowsy
# /home/data/manual_annotate/test80/Drowsy
# 4/4 [==============================] - 1s 16ms/step - loss: 0.6922 - accuracy: 0.5000
#
# ----------Baseline Model Test Results----------
#
# Baseline Test Acc. 50.00%
# -----------------------------------------------
# Epoch 1/40
# 15/15 [==============================] - 4s 27ms/step - loss: 0.8421 - accuracy: 0.4873 - val_loss: 0.6883 - val_accuracy: 0.4833
# Epoch 2/40
# 15/15 [==============================] - 0s 16ms/step - loss: 0.8203 - accuracy: 0.4916 - val_loss: 0.6879 - val_accuracy: 0.4833
# Epoch 3/40
# 15/15 [==============================] - 0s 14ms/step - loss: 0.7772 - accuracy: 0.5338 - val_loss: 0.6883 - val_accuracy: 0.4833
# Epoch 4/40
# 15/15 [==============================] - 0s 14ms/step - loss: 0.7547 - accuracy: 0.5654 - val_loss: 0.6843 - val_accuracy: 0.4833
# Epoch 5/40
# 15/15 [==============================] - 0s 14ms/step - loss: 0.7460 - accuracy: 0.5886 - val_loss: 0.6821 - val_accuracy: 0.4833
# Epoch 6/40
# 15/15 [==============================] - 0s 13ms/step - loss: 0.7373 - accuracy: 0.5823 - val_loss: 0.6822 - val_accuracy: 0.4833
# Epoch 7/40
# 15/15 [==============================] - 0s 14ms/step - loss: 0.6902 - accuracy: 0.6245 - val_loss: 0.6817 - val_accuracy: 0.4833
# Epoch 8/40
# 15/15 [==============================] - 0s 14ms/step - loss: 0.6627 - accuracy: 0.6456 - val_loss: 0.6790 - val_accuracy: 0.4833
# Epoch 9/40
# 15/15 [==============================] - 0s 14ms/step - loss: 0.6802 - accuracy: 0.5992 - val_loss: 0.6767 - val_accuracy: 0.4833
# Epoch 10/40
# 15/15 [==============================] - 0s 14ms/step - loss: 0.6426 - accuracy: 0.6582 - val_loss: 0.6741 - val_accuracy: 0.4833
# Epoch 11/40
# 15/15 [==============================] - 0s 14ms/step - loss: 0.6353 - accuracy: 0.6730 - val_loss: 0.6681 - val_accuracy: 0.4833
# Epoch 12/40
# 15/15 [==============================] - 0s 13ms/step - loss: 0.6322 - accuracy: 0.6899 - val_loss: 0.6632 - val_accuracy: 0.4833
# Epoch 13/40
# 15/15 [==============================] - 0s 13ms/step - loss: 0.5919 - accuracy: 0.7194 - val_loss: 0.6551 - val_accuracy: 0.4833
# Epoch 14/40
# 15/15 [==============================] - 0s 14ms/step - loss: 0.5742 - accuracy: 0.7046 - val_loss: 0.6444 - val_accuracy: 0.4833
# Epoch 15/40
# 15/15 [==============================] - 0s 14ms/step - loss: 0.5509 - accuracy: 0.7511 - val_loss: 0.6397 - val_accuracy: 0.4833
# Epoch 16/40
# 15/15 [==============================] - 0s 14ms/step - loss: 0.5473 - accuracy: 0.7489 - val_loss: 0.6341 - val_accuracy: 0.4833
# Epoch 17/40
# 15/15 [==============================] - 0s 15ms/step - loss: 0.5476 - accuracy: 0.7384 - val_loss: 0.6280 - val_accuracy: 0.4833
# Epoch 18/40
# 15/15 [==============================] - 0s 14ms/step - loss: 0.5070 - accuracy: 0.7743 - val_loss: 0.6101 - val_accuracy: 0.4833
# Epoch 19/40
# 15/15 [==============================] - 0s 14ms/step - loss: 0.4882 - accuracy: 0.7911 - val_loss: 0.5891 - val_accuracy: 0.5333
# Epoch 20/40
# 15/15 [==============================] - 0s 15ms/step - loss: 0.4782 - accuracy: 0.7827 - val_loss: 0.5825 - val_accuracy: 0.5500
# Epoch 21/40
# 15/15 [==============================] - 0s 15ms/step - loss: 0.4682 - accuracy: 0.7932 - val_loss: 0.5867 - val_accuracy: 0.5167
# Epoch 22/40
# 15/15 [==============================] - 0s 14ms/step - loss: 0.4565 - accuracy: 0.7975 - val_loss: 0.5653 - val_accuracy: 0.6000
# Epoch 23/40
# 15/15 [==============================] - 0s 14ms/step - loss: 0.4373 - accuracy: 0.7996 - val_loss: 0.5517 - val_accuracy: 0.6333
# Epoch 24/40
# 15/15 [==============================] - 0s 14ms/step - loss: 0.4417 - accuracy: 0.8080 - val_loss: 0.5359 - val_accuracy: 0.6667
# Epoch 25/40
# 15/15 [==============================] - 0s 14ms/step - loss: 0.4072 - accuracy: 0.8354 - val_loss: 0.5360 - val_accuracy: 0.6167
# Epoch 26/40
# 15/15 [==============================] - 0s 14ms/step - loss: 0.4228 - accuracy: 0.8186 - val_loss: 0.5148 - val_accuracy: 0.6500
# Epoch 27/40
# 15/15 [==============================] - 0s 15ms/step - loss: 0.3716 - accuracy: 0.8460 - val_loss: 0.4846 - val_accuracy: 0.6833
# Epoch 28/40
# 15/15 [==============================] - 0s 14ms/step - loss: 0.3482 - accuracy: 0.8755 - val_loss: 0.4631 - val_accuracy: 0.7167
# Epoch 29/40
# 15/15 [==============================] - 0s 14ms/step - loss: 0.3755 - accuracy: 0.8291 - val_loss: 0.4519 - val_accuracy: 0.6667
# Epoch 30/40
# 15/15 [==============================] - 0s 14ms/step - loss: 0.3607 - accuracy: 0.8502 - val_loss: 0.4297 - val_accuracy: 0.7333
# Epoch 31/40
# 15/15 [==============================] - 0s 14ms/step - loss: 0.3750 - accuracy: 0.8354 - val_loss: 0.4063 - val_accuracy: 0.8000
# Epoch 32/40
# 15/15 [==============================] - 0s 14ms/step - loss: 0.3588 - accuracy: 0.8544 - val_loss: 0.3881 - val_accuracy: 0.8167
# Epoch 33/40
# 15/15 [==============================] - 0s 14ms/step - loss: 0.3268 - accuracy: 0.8692 - val_loss: 0.4018 - val_accuracy: 0.7333
# Epoch 34/40
# 15/15 [==============================] - 0s 15ms/step - loss: 0.3280 - accuracy: 0.8734 - val_loss: 0.3983 - val_accuracy: 0.7333
# Epoch 35/40
# 15/15 [==============================] - 0s 14ms/step - loss: 0.3183 - accuracy: 0.8819 - val_loss: 0.4324 - val_accuracy: 0.6667
# Epoch 36/40
# 15/15 [==============================] - 0s 14ms/step - loss: 0.2725 - accuracy: 0.9072 - val_loss: 0.3910 - val_accuracy: 0.6833
# Epoch 37/40
# 15/15 [==============================] - 0s 14ms/step - loss: 0.3080 - accuracy: 0.8797 - val_loss: 0.3529 - val_accuracy: 0.8000
# Epoch 38/40
# 15/15 [==============================] - 0s 15ms/step - loss: 0.2594 - accuracy: 0.9093 - val_loss: 0.3375 - val_accuracy: 0.8000
# Epoch 39/40
# 15/15 [==============================] - 0s 15ms/step - loss: 0.2785 - accuracy: 0.8924 - val_loss: 0.3200 - val_accuracy: 0.8333
# Epoch 40/40
# 15/15 [==============================] - 0s 14ms/step - loss: 0.2722 - accuracy: 0.8861 - val_loss: 0.3053 - val_accuracy: 0.8500
# /home/data/manual_annotate/test80/NonDrowsy
# /home/data/manual_annotate/test80/Drowsy
# 4/4 [==============================] - 0s 8ms/step - loss: 0.4838 - accuracy: 0.7200
#
# ----------Model Test Accuracy Results----------
#
# Test Acc. 72.00%
# -----------------------------------------------
# /home/data/manual_annotate/train80/NonDrowsy
# /home/data/manual_annotate/train80/Drowsy
#
# ----------Preprocessing Summary----------
# images shape (300, 80, 80, 3)
# y shape (300,)
# X_train shape (474, 80, 80, 3)
# y_train shape (474,)
# X_val shape (60, 80, 80, 3)
# y_val shape (60,)
# X_test shape (3, 80, 80, 3)
# y_test shape (3,)
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv_1 (Conv2D)             (None, 80, 80, 16)        1216
#
#  batch_normalization (Batch  (None, 80, 80, 16)        64
#  Normalization)
#
#  activation (Activation)     (None, 80, 80, 16)        0
#
#  dropout (Dropout)           (None, 80, 80, 16)        0
#
#  pool_1 (MaxPooling2D)       (None, 40, 40, 16)        0
#
#  conv_2 (Conv2D)             (None, 40, 40, 16)        6416
#
#  batch_normalization_1 (Bat  (None, 40, 40, 16)        64
#  chNormalization)
#
#  activation_1 (Activation)   (None, 40, 40, 16)        0
#
#  pool_2 (MaxPooling2D)       (None, 20, 20, 16)        0
#
#  dropout_1 (Dropout)         (None, 20, 20, 16)        0
#
#  flatten (Flatten)           (None, 6400)              0
#
#  fc_1 (Dense)                (None, 128)               819328
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  fc_2 (Dense)                (None, 64)                8256
#
#  batch_normalization_2 (Bat  (None, 64)                256
#  chNormalization)
#
#  activation_2 (Activation)   (None, 64)                0
#
#  fc_3 (Dense)                (None, 32)                2080
#
#  batch_normalization_3 (Bat  (None, 32)                128
#  chNormalization)
#
#  activation_3 (Activation)   (None, 32)                0
#
#  fc_4 (Dense)                (None, 1)                 33
#
# =================================================================
# Total params: 837841 (3.20 MB)
# Trainable params: 837585 (3.20 MB)
# Non-trainable params: 256 (1.00 KB)
# _________________________________________________________________
# /home/data/manual_annotate/test80/NonDrowsy
# /home/data/manual_annotate/test80/Drowsy
# 4/4 [==============================] - 0s 8ms/step - loss: 0.6910 - accuracy: 0.5000
#
# ----------Baseline Model Test Results----------
#
# Baseline Test Acc. 50.00%
# -----------------------------------------------
# Epoch 1/40
# 15/15 [==============================] - 4s 25ms/step - loss: 0.8065 - accuracy: 0.5084 - val_loss: 0.6941 - val_accuracy: 0.4833
# Epoch 2/40
# 15/15 [==============================] - 0s 18ms/step - loss: 0.7485 - accuracy: 0.5021 - val_loss: 0.6949 - val_accuracy: 0.4833
# Epoch 3/40
# 15/15 [==============================] - 0s 16ms/step - loss: 0.7233 - accuracy: 0.5127 - val_loss: 0.6943 - val_accuracy: 0.4833
# Epoch 4/40
# 15/15 [==============================] - 0s 15ms/step - loss: 0.6968 - accuracy: 0.5190 - val_loss: 0.6914 - val_accuracy: 0.4833
# Epoch 5/40
# 15/15 [==============================] - 0s 15ms/step - loss: 0.7020 - accuracy: 0.5063 - val_loss: 0.6904 - val_accuracy: 0.4833
# Epoch 6/40
# 15/15 [==============================] - 0s 15ms/step - loss: 0.7029 - accuracy: 0.5464 - val_loss: 0.6911 - val_accuracy: 0.4833
# Epoch 7/40
# 15/15 [==============================] - 0s 14ms/step - loss: 0.7012 - accuracy: 0.5401 - val_loss: 0.6912 - val_accuracy: 0.4833
# Epoch 8/40
# 15/15 [==============================] - 0s 14ms/step - loss: 0.6868 - accuracy: 0.5232 - val_loss: 0.6928 - val_accuracy: 0.4833
# Epoch 9/40
# 15/15 [==============================] - 0s 14ms/step - loss: 0.6589 - accuracy: 0.5443 - val_loss: 0.6954 - val_accuracy: 0.4833
# Epoch 10/40
# 15/15 [==============================] - 0s 16ms/step - loss: 0.6382 - accuracy: 0.5612 - val_loss: 0.7004 - val_accuracy: 0.4833
# Epoch 11/40
# 15/15 [==============================] - 0s 13ms/step - loss: 0.6298 - accuracy: 0.5717 - val_loss: 0.7022 - val_accuracy: 0.4833
# Epoch 12/40
# 15/15 [==============================] - 0s 14ms/step - loss: 0.6198 - accuracy: 0.5759 - val_loss: 0.7083 - val_accuracy: 0.4833
# Epoch 13/40
# 15/15 [==============================] - 0s 14ms/step - loss: 0.6134 - accuracy: 0.5970 - val_loss: 0.7100 - val_accuracy: 0.4833
# Epoch 14/40
# 15/15 [==============================] - 0s 14ms/step - loss: 0.5822 - accuracy: 0.6097 - val_loss: 0.7053 - val_accuracy: 0.4833
# Epoch 15/40
# 15/15 [==============================] - 0s 14ms/step - loss: 0.5763 - accuracy: 0.6203 - val_loss: 0.7020 - val_accuracy: 0.4833
# Epoch 16/40
# 15/15 [==============================] - 0s 14ms/step - loss: 0.5898 - accuracy: 0.6055 - val_loss: 0.6919 - val_accuracy: 0.4833
# Epoch 17/40
# 15/15 [==============================] - 0s 16ms/step - loss: 0.5406 - accuracy: 0.6624 - val_loss: 0.6828 - val_accuracy: 0.4833
# Epoch 18/40
# 15/15 [==============================] - 0s 14ms/step - loss: 0.5529 - accuracy: 0.6582 - val_loss: 0.6878 - val_accuracy: 0.4833
# Epoch 19/40
# 15/15 [==============================] - 0s 14ms/step - loss: 0.5128 - accuracy: 0.6814 - val_loss: 0.6693 - val_accuracy: 0.4833
# Epoch 20/40
# 15/15 [==============================] - 0s 15ms/step - loss: 0.4896 - accuracy: 0.7046 - val_loss: 0.6591 - val_accuracy: 0.4833
# Epoch 21/40
# 15/15 [==============================] - 0s 14ms/step - loss: 0.4820 - accuracy: 0.7110 - val_loss: 0.6277 - val_accuracy: 0.4833
# Epoch 22/40
# 15/15 [==============================] - 0s 15ms/step - loss: 0.4939 - accuracy: 0.7025 - val_loss: 0.5959 - val_accuracy: 0.4833
# Epoch 23/40
# 15/15 [==============================] - 0s 14ms/step - loss: 0.4694 - accuracy: 0.7152 - val_loss: 0.5683 - val_accuracy: 0.5000
# Epoch 24/40
# 15/15 [==============================] - 0s 14ms/step - loss: 0.4758 - accuracy: 0.7194 - val_loss: 0.5500 - val_accuracy: 0.5167
# Epoch 25/40
# 15/15 [==============================] - 0s 15ms/step - loss: 0.4229 - accuracy: 0.7553 - val_loss: 0.5578 - val_accuracy: 0.5167
# Epoch 26/40
# 15/15 [==============================] - 0s 14ms/step - loss: 0.4366 - accuracy: 0.7806 - val_loss: 0.5348 - val_accuracy: 0.5667
# Epoch 27/40
# 15/15 [==============================] - 0s 14ms/step - loss: 0.4242 - accuracy: 0.7722 - val_loss: 0.5131 - val_accuracy: 0.5833
# Epoch 28/40
# 15/15 [==============================] - 0s 13ms/step - loss: 0.4026 - accuracy: 0.7848 - val_loss: 0.4908 - val_accuracy: 0.6667
# Epoch 29/40
# 15/15 [==============================] - 0s 14ms/step - loss: 0.3896 - accuracy: 0.8017 - val_loss: 0.4572 - val_accuracy: 0.7333
# Epoch 30/40
# 15/15 [==============================] - 0s 14ms/step - loss: 0.3920 - accuracy: 0.7975 - val_loss: 0.4468 - val_accuracy: 0.7333
# Epoch 31/40
# 15/15 [==============================] - 0s 13ms/step - loss: 0.3846 - accuracy: 0.8165 - val_loss: 0.4441 - val_accuracy: 0.6833
# Epoch 32/40
# 15/15 [==============================] - 0s 14ms/step - loss: 0.3643 - accuracy: 0.8333 - val_loss: 0.4268 - val_accuracy: 0.7333
# Epoch 33/40
# 15/15 [==============================] - 0s 16ms/step - loss: 0.3466 - accuracy: 0.8397 - val_loss: 0.4066 - val_accuracy: 0.7667
# Epoch 34/40
# 15/15 [==============================] - 0s 14ms/step - loss: 0.3286 - accuracy: 0.8544 - val_loss: 0.3881 - val_accuracy: 0.7667
# Epoch 35/40
# 15/15 [==============================] - 0s 15ms/step - loss: 0.3181 - accuracy: 0.8439 - val_loss: 0.3941 - val_accuracy: 0.7167
# Epoch 36/40
# 15/15 [==============================] - 0s 15ms/step - loss: 0.3111 - accuracy: 0.8671 - val_loss: 0.3895 - val_accuracy: 0.7500
# Epoch 37/40
# 15/15 [==============================] - 0s 14ms/step - loss: 0.3234 - accuracy: 0.8713 - val_loss: 0.3399 - val_accuracy: 0.7833
# Epoch 38/40
# 15/15 [==============================] - 0s 14ms/step - loss: 0.3006 - accuracy: 0.8734 - val_loss: 0.3388 - val_accuracy: 0.8000
# Epoch 39/40
# 15/15 [==============================] - 0s 14ms/step - loss: 0.2760 - accuracy: 0.8797 - val_loss: 0.3416 - val_accuracy: 0.8000
# Epoch 40/40
# 15/15 [==============================] - 0s 14ms/step - loss: 0.2925 - accuracy: 0.8840 - val_loss: 0.3262 - val_accuracy: 0.8167
# /home/data/manual_annotate/test80/NonDrowsy
# /home/data/manual_annotate/test80/Drowsy
# 4/4 [==============================] - 0s 7ms/step - loss: 0.5673 - accuracy: 0.7800
#
# ----------Model Test Accuracy Results----------
#
# Test Acc. 78.00%
# -----------------------------------------------
# /home/data/manual_annotate/train80/NonDrowsy
# /home/data/manual_annotate/train80/Drowsy
#
# ----------Preprocessing Summary----------
# images shape (300, 80, 80, 3)
# y shape (300,)
# X_train shape (474, 80, 80, 3)
# y_train shape (474,)
# X_val shape (60, 80, 80, 3)
# y_val shape (60,)
# X_test shape (3, 80, 80, 3)
# y_test shape (3,)
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv_1 (Conv2D)             (None, 80, 80, 16)        1216
#
#  batch_normalization (Batch  (None, 80, 80, 16)        64
#  Normalization)
#
#  activation (Activation)     (None, 80, 80, 16)        0
#
#  dropout (Dropout)           (None, 80, 80, 16)        0
#
#  pool_1 (MaxPooling2D)       (None, 40, 40, 16)        0
#
#  conv_2 (Conv2D)             (None, 40, 40, 16)        6416
#
#  batch_normalization_1 (Bat  (None, 40, 40, 16)        64
#  chNormalization)
#
#  activation_1 (Activation)   (None, 40, 40, 16)        0
#
#  pool_2 (MaxPooling2D)       (None, 20, 20, 16)        0
#
#  dropout_1 (Dropout)         (None, 20, 20, 16)        0
#
#  flatten (Flatten)           (None, 6400)              0
#
#  fc_1 (Dense)                (None, 128)               819328
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  fc_2 (Dense)                (None, 64)                8256
#
#  batch_normalization_2 (Bat  (None, 64)                256
#  chNormalization)
#
#  activation_2 (Activation)   (None, 64)                0
#
#  fc_3 (Dense)                (None, 32)                2080
#
#  batch_normalization_3 (Bat  (None, 32)                128
#  chNormalization)
#
#  activation_3 (Activation)   (None, 32)                0
#
#  fc_4 (Dense)                (None, 1)                 33
#
# =================================================================
# Total params: 837841 (3.20 MB)
# Trainable params: 837585 (3.20 MB)
# Non-trainable params: 256 (1.00 KB)
# _________________________________________________________________
# /home/data/manual_annotate/test80/NonDrowsy
# /home/data/manual_annotate/test80/Drowsy
# 4/4 [==============================] - 0s 8ms/step - loss: 0.6927 - accuracy: 0.5000
#
# ----------Baseline Model Test Results----------
#
# Baseline Test Acc. 50.00%
# -----------------------------------------------
# Epoch 1/40
# 15/15 [==============================] - 5s 43ms/step - loss: 0.7905 - accuracy: 0.5127 - val_loss: 0.6919 - val_accuracy: 0.4833
# Epoch 2/40
# 15/15 [==============================] - 0s 23ms/step - loss: 0.7330 - accuracy: 0.5042 - val_loss: 0.6943 - val_accuracy: 0.4833
# Epoch 3/40
# 15/15 [==============================] - 0s 19ms/step - loss: 0.6906 - accuracy: 0.5338 - val_loss: 0.6956 - val_accuracy: 0.4833
# Epoch 4/40
# 15/15 [==============================] - 0s 18ms/step - loss: 0.6857 - accuracy: 0.5464 - val_loss: 0.6958 - val_accuracy: 0.4833
# Epoch 5/40
# 15/15 [==============================] - 0s 21ms/step - loss: 0.6701 - accuracy: 0.5823 - val_loss: 0.6954 - val_accuracy: 0.4833
# Epoch 6/40
# 15/15 [==============================] - 0s 19ms/step - loss: 0.6736 - accuracy: 0.5928 - val_loss: 0.6932 - val_accuracy: 0.4833
# Epoch 7/40
# 15/15 [==============================] - 0s 16ms/step - loss: 0.6383 - accuracy: 0.6224 - val_loss: 0.6956 - val_accuracy: 0.4833
# Epoch 8/40
# 15/15 [==============================] - 0s 18ms/step - loss: 0.6219 - accuracy: 0.6456 - val_loss: 0.6907 - val_accuracy: 0.4833
# Epoch 9/40
# 15/15 [==============================] - 0s 18ms/step - loss: 0.6206 - accuracy: 0.6181 - val_loss: 0.6866 - val_accuracy: 0.4833
# Epoch 10/40
# 15/15 [==============================] - 0s 18ms/step - loss: 0.6079 - accuracy: 0.6203 - val_loss: 0.6880 - val_accuracy: 0.4833
# Epoch 11/40
# 15/15 [==============================] - 0s 17ms/step - loss: 0.5666 - accuracy: 0.6709 - val_loss: 0.6926 - val_accuracy: 0.4833
# Epoch 12/40
# 15/15 [==============================] - 0s 14ms/step - loss: 0.5705 - accuracy: 0.6624 - val_loss: 0.7112 - val_accuracy: 0.4833
# Epoch 13/40
# 15/15 [==============================] - 0s 14ms/step - loss: 0.5479 - accuracy: 0.6920 - val_loss: 0.7034 - val_accuracy: 0.4833
# Epoch 14/40
# 15/15 [==============================] - 0s 16ms/step - loss: 0.5189 - accuracy: 0.6941 - val_loss: 0.7044 - val_accuracy: 0.4833
# Epoch 15/40
# 15/15 [==============================] - 0s 15ms/step - loss: 0.5359 - accuracy: 0.7173 - val_loss: 0.7053 - val_accuracy: 0.4833
# Epoch 16/40
# 15/15 [==============================] - 0s 15ms/step - loss: 0.5150 - accuracy: 0.7194 - val_loss: 0.6749 - val_accuracy: 0.4833
# Epoch 17/40
# 15/15 [==============================] - 0s 15ms/step - loss: 0.5019 - accuracy: 0.7426 - val_loss: 0.6693 - val_accuracy: 0.4833
# Epoch 18/40
# 15/15 [==============================] - 0s 15ms/step - loss: 0.4696 - accuracy: 0.7722 - val_loss: 0.6328 - val_accuracy: 0.4833
# Epoch 19/40
# 15/15 [==============================] - 0s 14ms/step - loss: 0.4504 - accuracy: 0.7975 - val_loss: 0.6125 - val_accuracy: 0.5167
# Epoch 20/40
# 15/15 [==============================] - 0s 15ms/step - loss: 0.4625 - accuracy: 0.7848 - val_loss: 0.6278 - val_accuracy: 0.5167
# Epoch 21/40
# 15/15 [==============================] - 0s 15ms/step - loss: 0.4299 - accuracy: 0.7975 - val_loss: 0.6200 - val_accuracy: 0.5333
# Epoch 22/40
# 15/15 [==============================] - 0s 14ms/step - loss: 0.4447 - accuracy: 0.7869 - val_loss: 0.5684 - val_accuracy: 0.5667
# Epoch 23/40
# 15/15 [==============================] - 0s 16ms/step - loss: 0.4293 - accuracy: 0.7911 - val_loss: 0.5304 - val_accuracy: 0.6000
# Epoch 24/40
# 15/15 [==============================] - 0s 15ms/step - loss: 0.4254 - accuracy: 0.7911 - val_loss: 0.5030 - val_accuracy: 0.6667
# Epoch 25/40
# 15/15 [==============================] - 0s 16ms/step - loss: 0.3991 - accuracy: 0.8080 - val_loss: 0.4986 - val_accuracy: 0.6500
# Epoch 26/40
# 15/15 [==============================] - 0s 15ms/step - loss: 0.3934 - accuracy: 0.8207 - val_loss: 0.5066 - val_accuracy: 0.6333
# Epoch 27/40
# 15/15 [==============================] - 0s 16ms/step - loss: 0.3620 - accuracy: 0.8544 - val_loss: 0.5895 - val_accuracy: 0.5667
# Epoch 28/40
# 15/15 [==============================] - 0s 14ms/step - loss: 0.3784 - accuracy: 0.8354 - val_loss: 0.5026 - val_accuracy: 0.6667
# Epoch 29/40
# 15/15 [==============================] - 0s 13ms/step - loss: 0.3470 - accuracy: 0.8565 - val_loss: 0.4437 - val_accuracy: 0.7167
# Epoch 30/40
# 15/15 [==============================] - 0s 14ms/step - loss: 0.3212 - accuracy: 0.8840 - val_loss: 0.4420 - val_accuracy: 0.7167
# Epoch 31/40
# 15/15 [==============================] - 0s 15ms/step - loss: 0.3149 - accuracy: 0.8650 - val_loss: 0.4201 - val_accuracy: 0.7333
# Epoch 32/40
# 15/15 [==============================] - 0s 15ms/step - loss: 0.3169 - accuracy: 0.8692 - val_loss: 0.4129 - val_accuracy: 0.7333
# Epoch 33/40
# 15/15 [==============================] - 0s 15ms/step - loss: 0.3190 - accuracy: 0.8586 - val_loss: 0.3904 - val_accuracy: 0.7667
# Epoch 34/40
# 15/15 [==============================] - 0s 17ms/step - loss: 0.2881 - accuracy: 0.8903 - val_loss: 0.4252 - val_accuracy: 0.7167
# Epoch 35/40
# 15/15 [==============================] - 0s 15ms/step - loss: 0.2955 - accuracy: 0.8840 - val_loss: 0.4037 - val_accuracy: 0.7333
# Epoch 36/40
# 15/15 [==============================] - 0s 16ms/step - loss: 0.2785 - accuracy: 0.9008 - val_loss: 0.3354 - val_accuracy: 0.8167
# Epoch 37/40
# 15/15 [==============================] - 0s 14ms/step - loss: 0.2865 - accuracy: 0.8882 - val_loss: 0.3322 - val_accuracy: 0.8000
# Epoch 38/40
# 15/15 [==============================] - 0s 14ms/step - loss: 0.2753 - accuracy: 0.8945 - val_loss: 0.3494 - val_accuracy: 0.7667
# Epoch 39/40
# 15/15 [==============================] - 0s 16ms/step - loss: 0.2753 - accuracy: 0.9008 - val_loss: 0.3339 - val_accuracy: 0.7833
# Epoch 40/40
# 15/15 [==============================] - 0s 15ms/step - loss: 0.2413 - accuracy: 0.9093 - val_loss: 0.3066 - val_accuracy: 0.8000
# /home/data/manual_annotate/test80/NonDrowsy
# /home/data/manual_annotate/test80/Drowsy
# 4/4 [==============================] - 0s 8ms/step - loss: 0.5491 - accuracy: 0.6900
#
# ----------Model Test Accuracy Results----------
#
# Test Acc. 69.00%
# -----------------------------------------------
# /home/data/manual_annotate/train80/NonDrowsy
# /home/data/manual_annotate/train80/Drowsy
#
# ----------Preprocessing Summary----------
# images shape (300, 80, 80, 3)
# y shape (300,)
# X_train shape (474, 80, 80, 3)
# y_train shape (474,)
# X_val shape (60, 80, 80, 3)
# y_val shape (60,)
# X_test shape (3, 80, 80, 3)
# y_test shape (3,)
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv_1 (Conv2D)             (None, 80, 80, 16)        1216
#
#  batch_normalization (Batch  (None, 80, 80, 16)        64
#  Normalization)
#
#  activation (Activation)     (None, 80, 80, 16)        0
#
#  dropout (Dropout)           (None, 80, 80, 16)        0
#
#  pool_1 (MaxPooling2D)       (None, 40, 40, 16)        0
#
#  conv_2 (Conv2D)             (None, 40, 40, 16)        6416
#
#  batch_normalization_1 (Bat  (None, 40, 40, 16)        64
#  chNormalization)
#
#  activation_1 (Activation)   (None, 40, 40, 16)        0
#
#  pool_2 (MaxPooling2D)       (None, 20, 20, 16)        0
#
#  dropout_1 (Dropout)         (None, 20, 20, 16)        0
#
#  flatten (Flatten)           (None, 6400)              0
#
#  fc_1 (Dense)                (None, 128)               819328
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  fc_2 (Dense)                (None, 64)                8256
#
#  batch_normalization_2 (Bat  (None, 64)                256
#  chNormalization)
#
#  activation_2 (Activation)   (None, 64)                0
#
#  fc_3 (Dense)                (None, 32)                2080
#
#  batch_normalization_3 (Bat  (None, 32)                128
#  chNormalization)
#
#  activation_3 (Activation)   (None, 32)                0
#
#  fc_4 (Dense)                (None, 1)                 33
#
# =================================================================
# Total params: 837841 (3.20 MB)
# Trainable params: 837585 (3.20 MB)
# Non-trainable params: 256 (1.00 KB)
# _________________________________________________________________
# /home/data/manual_annotate/test80/NonDrowsy
# /home/data/manual_annotate/test80/Drowsy
# 4/4 [==============================] - 0s 8ms/step - loss: 0.6861 - accuracy: 0.5000
#
# ----------Baseline Model Test Results----------
#
# Baseline Test Acc. 50.00%
# -----------------------------------------------
# Epoch 1/40
# 15/15 [==============================] - 6s 34ms/step - loss: 0.9290 - accuracy: 0.5063 - val_loss: 0.7009 - val_accuracy: 0.4833
# Epoch 2/40
# 15/15 [==============================] - 0s 19ms/step - loss: 0.9095 - accuracy: 0.5063 - val_loss: 0.7042 - val_accuracy: 0.4833
# Epoch 3/40
# 15/15 [==============================] - 0s 20ms/step - loss: 0.8875 - accuracy: 0.5000 - val_loss: 0.7070 - val_accuracy: 0.4833
# Epoch 4/40
# 15/15 [==============================] - 0s 19ms/step - loss: 0.8546 - accuracy: 0.5063 - val_loss: 0.7042 - val_accuracy: 0.4833
# Epoch 5/40
# 15/15 [==============================] - 0s 18ms/step - loss: 0.8511 - accuracy: 0.5127 - val_loss: 0.7013 - val_accuracy: 0.4833
# Epoch 6/40
# 15/15 [==============================] - 0s 17ms/step - loss: 0.8103 - accuracy: 0.5084 - val_loss: 0.7095 - val_accuracy: 0.4833
# Epoch 7/40
# 15/15 [==============================] - 0s 15ms/step - loss: 0.7856 - accuracy: 0.5169 - val_loss: 0.7149 - val_accuracy: 0.4833
# Epoch 8/40
# 15/15 [==============================] - 0s 16ms/step - loss: 0.7706 - accuracy: 0.5169 - val_loss: 0.7218 - val_accuracy: 0.4833
# Epoch 9/40
# 15/15 [==============================] - 0s 14ms/step - loss: 0.7596 - accuracy: 0.5211 - val_loss: 0.7144 - val_accuracy: 0.4833
# Epoch 10/40
# 15/15 [==============================] - 0s 15ms/step - loss: 0.7543 - accuracy: 0.5169 - val_loss: 0.7213 - val_accuracy: 0.4833
# Epoch 11/40
# 15/15 [==============================] - 0s 16ms/step - loss: 0.7372 - accuracy: 0.5211 - val_loss: 0.7104 - val_accuracy: 0.4833
# Epoch 12/40
# 15/15 [==============================] - 0s 14ms/step - loss: 0.6994 - accuracy: 0.5338 - val_loss: 0.7148 - val_accuracy: 0.4833
# Epoch 13/40
# 15/15 [==============================] - 0s 15ms/step - loss: 0.6761 - accuracy: 0.5338 - val_loss: 0.7113 - val_accuracy: 0.4833
# Epoch 14/40
# 15/15 [==============================] - 0s 15ms/step - loss: 0.6791 - accuracy: 0.5316 - val_loss: 0.7020 - val_accuracy: 0.4833
# Epoch 15/40
# 15/15 [==============================] - 0s 15ms/step - loss: 0.6892 - accuracy: 0.5211 - val_loss: 0.6952 - val_accuracy: 0.4833
# Epoch 16/40
# 15/15 [==============================] - 0s 16ms/step - loss: 0.6448 - accuracy: 0.5485 - val_loss: 0.6864 - val_accuracy: 0.4833
# Epoch 17/40
# 15/15 [==============================] - 0s 16ms/step - loss: 0.6411 - accuracy: 0.5338 - val_loss: 0.6832 - val_accuracy: 0.4833
# Epoch 18/40
# 15/15 [==============================] - 0s 15ms/step - loss: 0.6459 - accuracy: 0.5401 - val_loss: 0.6832 - val_accuracy: 0.4833
# Epoch 19/40
# 15/15 [==============================] - 0s 15ms/step - loss: 0.5904 - accuracy: 0.5549 - val_loss: 0.6689 - val_accuracy: 0.4833
# Epoch 20/40
# 15/15 [==============================] - 0s 14ms/step - loss: 0.5950 - accuracy: 0.5464 - val_loss: 0.6773 - val_accuracy: 0.4833
# Epoch 21/40
# 15/15 [==============================] - 0s 16ms/step - loss: 0.6061 - accuracy: 0.5506 - val_loss: 0.6617 - val_accuracy: 0.4833
# Epoch 22/40
# 15/15 [==============================] - 0s 16ms/step - loss: 0.5888 - accuracy: 0.5591 - val_loss: 0.6367 - val_accuracy: 0.4833
# Epoch 23/40
# 15/15 [==============================] - 0s 15ms/step - loss: 0.5476 - accuracy: 0.5781 - val_loss: 0.6292 - val_accuracy: 0.4833
# Epoch 24/40
# 15/15 [==============================] - 0s 16ms/step - loss: 0.5370 - accuracy: 0.5865 - val_loss: 0.6138 - val_accuracy: 0.4833
# Epoch 25/40
# 15/15 [==============================] - 0s 15ms/step - loss: 0.5225 - accuracy: 0.5992 - val_loss: 0.5985 - val_accuracy: 0.4833
# Epoch 26/40
# 15/15 [==============================] - 0s 15ms/step - loss: 0.4981 - accuracy: 0.6118 - val_loss: 0.5802 - val_accuracy: 0.4833
# Epoch 27/40
# 15/15 [==============================] - 0s 14ms/step - loss: 0.4818 - accuracy: 0.6160 - val_loss: 0.5602 - val_accuracy: 0.4833
# Epoch 28/40
# 15/15 [==============================] - 0s 16ms/step - loss: 0.4877 - accuracy: 0.6203 - val_loss: 0.5607 - val_accuracy: 0.4833
# Epoch 29/40
# 15/15 [==============================] - 0s 16ms/step - loss: 0.4640 - accuracy: 0.6435 - val_loss: 0.5656 - val_accuracy: 0.4833
# Epoch 30/40
# 15/15 [==============================] - 0s 16ms/step - loss: 0.4386 - accuracy: 0.6624 - val_loss: 0.5471 - val_accuracy: 0.4833
# Epoch 31/40
# 15/15 [==============================] - 0s 14ms/step - loss: 0.4595 - accuracy: 0.6835 - val_loss: 0.5166 - val_accuracy: 0.4833
# Epoch 32/40
# 15/15 [==============================] - 0s 16ms/step - loss: 0.4308 - accuracy: 0.6814 - val_loss: 0.5052 - val_accuracy: 0.4833
# Epoch 33/40
# 15/15 [==============================] - 0s 21ms/step - loss: 0.4381 - accuracy: 0.6920 - val_loss: 0.4916 - val_accuracy: 0.4833
# Epoch 34/40
# 15/15 [==============================] - 0s 33ms/step - loss: 0.3977 - accuracy: 0.7194 - val_loss: 0.4616 - val_accuracy: 0.6000
# Epoch 35/40
# 15/15 [==============================] - 0s 23ms/step - loss: 0.3908 - accuracy: 0.7384 - val_loss: 0.4577 - val_accuracy: 0.6667
# Epoch 36/40
# 15/15 [==============================] - 0s 23ms/step - loss: 0.3740 - accuracy: 0.7679 - val_loss: 0.4384 - val_accuracy: 0.7167
# Epoch 37/40
# 15/15 [==============================] - 0s 15ms/step - loss: 0.3631 - accuracy: 0.7595 - val_loss: 0.4592 - val_accuracy: 0.6000
# Epoch 38/40
# 15/15 [==============================] - 0s 15ms/step - loss: 0.3590 - accuracy: 0.7743 - val_loss: 0.4459 - val_accuracy: 0.6000
# Epoch 39/40
# 15/15 [==============================] - 0s 14ms/step - loss: 0.3557 - accuracy: 0.7954 - val_loss: 0.4020 - val_accuracy: 0.7500
# Epoch 40/40
# 15/15 [==============================] - 0s 15ms/step - loss: 0.3398 - accuracy: 0.8059 - val_loss: 0.3749 - val_accuracy: 0.8167
# /home/data/manual_annotate/test80/NonDrowsy
# /home/data/manual_annotate/test80/Drowsy
# 4/4 [==============================] - 0s 9ms/step - loss: 0.6621 - accuracy: 0.6300
#
# ----------Model Test Accuracy Results----------
#
# Test Acc. 63.00%
# -----------------------------------------------
# /home/data/manual_annotate/train80/NonDrowsy
# /home/data/manual_annotate/train80/Drowsy
#
# ----------Preprocessing Summary----------
# images shape (300, 80, 80, 3)
# y shape (300,)
# X_train shape (474, 80, 80, 3)
# y_train shape (474,)
# X_val shape (60, 80, 80, 3)
# y_val shape (60,)
# X_test shape (3, 80, 80, 3)
# y_test shape (3,)
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv_1 (Conv2D)             (None, 80, 80, 16)        1216
#
#  batch_normalization (Batch  (None, 80, 80, 16)        64
#  Normalization)
#
#  activation (Activation)     (None, 80, 80, 16)        0
#
#  dropout (Dropout)           (None, 80, 80, 16)        0
#
#  pool_1 (MaxPooling2D)       (None, 40, 40, 16)        0
#
#  conv_2 (Conv2D)             (None, 40, 40, 16)        6416
#
#  batch_normalization_1 (Bat  (None, 40, 40, 16)        64
#  chNormalization)
#
#  activation_1 (Activation)   (None, 40, 40, 16)        0
#
#  pool_2 (MaxPooling2D)       (None, 20, 20, 16)        0
#
#  dropout_1 (Dropout)         (None, 20, 20, 16)        0
#
#  flatten (Flatten)           (None, 6400)              0
#
#  fc_1 (Dense)                (None, 128)               819328
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  fc_2 (Dense)                (None, 64)                8256
#
#  batch_normalization_2 (Bat  (None, 64)                256
#  chNormalization)
#
#  activation_2 (Activation)   (None, 64)                0
#
#  fc_3 (Dense)                (None, 32)                2080
#
#  batch_normalization_3 (Bat  (None, 32)                128
#  chNormalization)
#
#  activation_3 (Activation)   (None, 32)                0
#
#  fc_4 (Dense)                (None, 1)                 33
#
# =================================================================
# Total params: 837841 (3.20 MB)
# Trainable params: 837585 (3.20 MB)
# Non-trainable params: 256 (1.00 KB)
# _________________________________________________________________
# /home/data/manual_annotate/test80/NonDrowsy
# /home/data/manual_annotate/test80/Drowsy
# 4/4 [==============================] - 0s 8ms/step - loss: 0.6927 - accuracy: 0.5000
#
# ----------Baseline Model Test Results----------
#
# Baseline Test Acc. 50.00%
# -----------------------------------------------
# Epoch 1/40
# 15/15 [==============================] - 3s 25ms/step - loss: 0.7438 - accuracy: 0.5190 - val_loss: 0.6915 - val_accuracy: 0.4833
# Epoch 2/40
# 15/15 [==============================] - 0s 17ms/step - loss: 0.6902 - accuracy: 0.5485 - val_loss: 0.6937 - val_accuracy: 0.4833
# Epoch 3/40
# 15/15 [==============================] - 0s 17ms/step - loss: 0.6945 - accuracy: 0.5401 - val_loss: 0.6965 - val_accuracy: 0.4833
# Epoch 4/40
# 15/15 [==============================] - 0s 16ms/step - loss: 0.7035 - accuracy: 0.5422 - val_loss: 0.6976 - val_accuracy: 0.4833
# Epoch 5/40
# 15/15 [==============================] - 0s 16ms/step - loss: 0.6701 - accuracy: 0.5485 - val_loss: 0.6998 - val_accuracy: 0.4833
# Epoch 6/40
# 15/15 [==============================] - 0s 15ms/step - loss: 0.6851 - accuracy: 0.5485 - val_loss: 0.6991 - val_accuracy: 0.4833
# Epoch 7/40
# 15/15 [==============================] - 0s 16ms/step - loss: 0.6376 - accuracy: 0.5844 - val_loss: 0.6972 - val_accuracy: 0.4833
# Epoch 8/40
# 15/15 [==============================] - 0s 16ms/step - loss: 0.6591 - accuracy: 0.5485 - val_loss: 0.6962 - val_accuracy: 0.4833
# Epoch 9/40
# 15/15 [==============================] - 0s 16ms/step - loss: 0.6195 - accuracy: 0.5844 - val_loss: 0.6903 - val_accuracy: 0.4833
# Epoch 10/40
# 15/15 [==============================] - 0s 18ms/step - loss: 0.6072 - accuracy: 0.6160 - val_loss: 0.6895 - val_accuracy: 0.4833
# Epoch 11/40
# 15/15 [==============================] - 0s 20ms/step - loss: 0.6073 - accuracy: 0.6329 - val_loss: 0.6915 - val_accuracy: 0.4833
# Epoch 12/40
# 15/15 [==============================] - 0s 18ms/step - loss: 0.5915 - accuracy: 0.6435 - val_loss: 0.6878 - val_accuracy: 0.4833
# Epoch 13/40
# 15/15 [==============================] - 0s 18ms/step - loss: 0.5621 - accuracy: 0.6835 - val_loss: 0.6860 - val_accuracy: 0.4833
# Epoch 14/40
# 15/15 [==============================] - 0s 19ms/step - loss: 0.5377 - accuracy: 0.6920 - val_loss: 0.6691 - val_accuracy: 0.4833
# Epoch 15/40
# 15/15 [==============================] - 0s 18ms/step - loss: 0.5521 - accuracy: 0.6709 - val_loss: 0.6460 - val_accuracy: 0.4833
# Epoch 16/40
# 15/15 [==============================] - 0s 17ms/step - loss: 0.5306 - accuracy: 0.7089 - val_loss: 0.6376 - val_accuracy: 0.4833
# Epoch 17/40
# 15/15 [==============================] - 0s 19ms/step - loss: 0.5024 - accuracy: 0.7089 - val_loss: 0.6347 - val_accuracy: 0.4833
# Epoch 18/40
# 15/15 [==============================] - 0s 19ms/step - loss: 0.4973 - accuracy: 0.7447 - val_loss: 0.6462 - val_accuracy: 0.4833
# Epoch 19/40
# 15/15 [==============================] - 0s 19ms/step - loss: 0.4650 - accuracy: 0.7658 - val_loss: 0.6305 - val_accuracy: 0.4833
# Epoch 20/40
# 15/15 [==============================] - 0s 18ms/step - loss: 0.4557 - accuracy: 0.7532 - val_loss: 0.5783 - val_accuracy: 0.4833
# Epoch 21/40
# 15/15 [==============================] - 0s 18ms/step - loss: 0.4429 - accuracy: 0.7722 - val_loss: 0.5408 - val_accuracy: 0.5000
# Epoch 22/40
# 15/15 [==============================] - 0s 19ms/step - loss: 0.4428 - accuracy: 0.7722 - val_loss: 0.5224 - val_accuracy: 0.5500
# Epoch 23/40
# 15/15 [==============================] - 0s 18ms/step - loss: 0.4225 - accuracy: 0.7722 - val_loss: 0.5257 - val_accuracy: 0.5500
# Epoch 24/40
# 15/15 [==============================] - 0s 16ms/step - loss: 0.4394 - accuracy: 0.7658 - val_loss: 0.5022 - val_accuracy: 0.6000
# Epoch 25/40
# 15/15 [==============================] - 0s 18ms/step - loss: 0.4004 - accuracy: 0.8165 - val_loss: 0.4714 - val_accuracy: 0.7333
# Epoch 26/40
# 15/15 [==============================] - 0s 19ms/step - loss: 0.4024 - accuracy: 0.8038 - val_loss: 0.4689 - val_accuracy: 0.7333
# Epoch 27/40
# 15/15 [==============================] - 0s 20ms/step - loss: 0.3551 - accuracy: 0.8376 - val_loss: 0.4280 - val_accuracy: 0.7667
# Epoch 28/40
# 15/15 [==============================] - 0s 18ms/step - loss: 0.3790 - accuracy: 0.8122 - val_loss: 0.3996 - val_accuracy: 0.8000
# Epoch 29/40
# 15/15 [==============================] - 0s 18ms/step - loss: 0.3749 - accuracy: 0.8418 - val_loss: 0.3851 - val_accuracy: 0.8167
# Epoch 30/40
# 15/15 [==============================] - 0s 19ms/step - loss: 0.3743 - accuracy: 0.8354 - val_loss: 0.3817 - val_accuracy: 0.7833
# Epoch 31/40
# ...
#
# Baseline Test Acc. 50.00%
# -----------------------------------------------
# Epoch 1/40
# 15/15 [==============================] - 5s 31ms/step - loss: 0.7900 - accuracy: 0.5127 - val_loss: 0.6922 - val_accuracy: 0.4833
# Epoch 2/40
# 15/15 [==============================] - 0s 20ms/step - loss: 0.7535 - accuracy: 0.5316 - val_loss: 0.6918 - val_accuracy: 0.4833
# Epoch 3/40
# 15/15 [==============================] - 0s 23ms/step - loss: 0.7094 - accuracy: 0.6013 - val_loss: 0.6918 - val_accuracy: 0.4833
# Epoch 4/40
# 15/15 [==============================] - 0s 19ms/step - loss: 0.7159 - accuracy: 0.5422 - val_loss: 0.6945 - val_accuracy: 0.4833
# Epoch 5/40
# 15/15 [==============================] - 0s 19ms/step - loss: 0.7256 - accuracy: 0.5422 - val_loss: 0.6967 - val_accuracy: 0.4833
# Epoch 6/40
# 15/15 [==============================] - 0s 17ms/step - loss: 0.6896 - accuracy: 0.6013 - val_loss: 0.6982 - val_accuracy: 0.4833
# Epoch 7/40
# 15/15 [==============================] - 0s 19ms/step - loss: 0.6514 - accuracy: 0.6076 - val_loss: 0.6983 - val_accuracy: 0.4833
# Epoch 8/40
# 15/15 [==============================] - 0s 18ms/step - loss: 0.6478 - accuracy: 0.6561 - val_loss: 0.6943 - val_accuracy: 0.4833
# Epoch 9/40
# 15/15 [==============================] - 0s 21ms/step - loss: 0.6288 - accuracy: 0.6561 - val_loss: 0.6916 - val_accuracy: 0.4833
# Epoch 10/40
# 15/15 [==============================] - 0s 18ms/step - loss: 0.6407 - accuracy: 0.6667 - val_loss: 0.6900 - val_accuracy: 0.4833
# Epoch 11/40
# 15/15 [==============================] - 0s 15ms/step - loss: 0.6147 - accuracy: 0.6878 - val_loss: 0.6931 - val_accuracy: 0.4833
# Epoch 12/40
# 15/15 [==============================] - 0s 16ms/step - loss: 0.5807 - accuracy: 0.7004 - val_loss: 0.6890 - val_accuracy: 0.4833
# Epoch 13/40
# 15/15 [==============================] - 0s 16ms/step - loss: 0.5726 - accuracy: 0.7068 - val_loss: 0.6906 - val_accuracy: 0.4833
# Epoch 14/40
# 15/15 [==============================] - 0s 16ms/step - loss: 0.5940 - accuracy: 0.6983 - val_loss: 0.6885 - val_accuracy: 0.4833
# Epoch 15/40
# 15/15 [==============================] - 0s 15ms/step - loss: 0.5478 - accuracy: 0.7468 - val_loss: 0.6789 - val_accuracy: 0.4833
# Epoch 16/40
# 15/15 [==============================] - 0s 16ms/step - loss: 0.5529 - accuracy: 0.7405 - val_loss: 0.6726 - val_accuracy: 0.4833
# Epoch 17/40
# 15/15 [==============================] - 0s 15ms/step - loss: 0.5207 - accuracy: 0.7489 - val_loss: 0.6666 - val_accuracy: 0.4833
# Epoch 18/40
# 15/15 [==============================] - 0s 15ms/step - loss: 0.4915 - accuracy: 0.7700 - val_loss: 0.6557 - val_accuracy: 0.5000
# Epoch 19/40
# 15/15 [==============================] - 0s 16ms/step - loss: 0.4602 - accuracy: 0.8038 - val_loss: 0.6421 - val_accuracy: 0.5000
# Epoch 20/40
# 15/15 [==============================] - 0s 16ms/step - loss: 0.4632 - accuracy: 0.7848 - val_loss: 0.6243 - val_accuracy: 0.5167
# Epoch 21/40
# 15/15 [==============================] - 0s 15ms/step - loss: 0.4596 - accuracy: 0.8080 - val_loss: 0.6067 - val_accuracy: 0.5167
# Epoch 22/40
# 15/15 [==============================] - 0s 15ms/step - loss: 0.4600 - accuracy: 0.7869 - val_loss: 0.5926 - val_accuracy: 0.5667
# Epoch 23/40
# 15/15 [==============================] - 0s 15ms/step - loss: 0.4526 - accuracy: 0.7975 - val_loss: 0.5615 - val_accuracy: 0.5667
# Epoch 24/40
# 15/15 [==============================] - 0s 16ms/step - loss: 0.4230 - accuracy: 0.8080 - val_loss: 0.5347 - val_accuracy: 0.5833
# Epoch 25/40
# 15/15 [==============================] - 0s 16ms/step - loss: 0.3862 - accuracy: 0.8502 - val_loss: 0.5058 - val_accuracy: 0.6167
# Epoch 26/40
# 15/15 [==============================] - 0s 15ms/step - loss: 0.3809 - accuracy: 0.8586 - val_loss: 0.4764 - val_accuracy: 0.6667
# Epoch 27/40
# 15/15 [==============================] - 0s 16ms/step - loss: 0.3704 - accuracy: 0.8312 - val_loss: 0.4686 - val_accuracy: 0.6833
# Epoch 28/40
# 15/15 [==============================] - 0s 16ms/step - loss: 0.3653 - accuracy: 0.8481 - val_loss: 0.4699 - val_accuracy: 0.6500
# Epoch 29/40
# 15/15 [==============================] - 0s 15ms/step - loss: 0.3306 - accuracy: 0.8650 - val_loss: 0.4561 - val_accuracy: 0.6167
# Epoch 30/40
# 15/15 [==============================] - 0s 14ms/step - loss: 0.3345 - accuracy: 0.8650 - val_loss: 0.4376 - val_accuracy: 0.6833
# Epoch 31/40
# 15/15 [==============================] - 0s 16ms/step - loss: 0.3073 - accuracy: 0.8755 - val_loss: 0.4052 - val_accuracy: 0.7167
# Epoch 32/40
# 15/15 [==============================] - 0s 16ms/step - loss: 0.3319 - accuracy: 0.8629 - val_loss: 0.4005 - val_accuracy: 0.7000
# Epoch 33/40
# 15/15 [==============================] - 0s 17ms/step - loss: 0.3047 - accuracy: 0.8797 - val_loss: 0.3776 - val_accuracy: 0.7667
# Epoch 34/40
# 15/15 [==============================] - 0s 16ms/step - loss: 0.2957 - accuracy: 0.8819 - val_loss: 0.3570 - val_accuracy: 0.7667
# Epoch 35/40
# 15/15 [==============================] - 0s 15ms/step - loss: 0.2733 - accuracy: 0.8987 - val_loss: 0.3582 - val_accuracy: 0.7667
# Epoch 36/40
# 15/15 [==============================] - 0s 16ms/step - loss: 0.2672 - accuracy: 0.9093 - val_loss: 0.3485 - val_accuracy: 0.7833
# Epoch 37/40
# 15/15 [==============================] - 0s 16ms/step - loss: 0.2572 - accuracy: 0.9008 - val_loss: 0.3462 - val_accuracy: 0.7500
# Epoch 38/40
# 15/15 [==============================] - 0s 15ms/step - loss: 0.2647 - accuracy: 0.8945 - val_loss: 0.4130 - val_accuracy: 0.6667
# Epoch 39/40
# 15/15 [==============================] - 0s 16ms/step - loss: 0.2693 - accuracy: 0.9008 - val_loss: 0.3513 - val_accuracy: 0.7500
# Epoch 40/40
# 15/15 [==============================] - 0s 15ms/step - loss: 0.2581 - accuracy: 0.8987 - val_loss: 0.2872 - val_accuracy: 0.8500
# /home/data/manual_annotate/test80/NonDrowsy
# /home/data/manual_annotate/test80/Drowsy
# 4/4 [==============================] - 0s 8ms/step - loss: 0.5160 - accuracy: 0.7500
#
# ----------Model Test Accuracy Results----------
#
# Test Acc. 75.00%
# -----------------------------------------------
# /home/data/manual_annotate/train80/NonDrowsy
# /home/data/manual_annotate/train80/Drowsy
#
# ----------Preprocessing Summary----------
# images shape (300, 80, 80, 3)
# y shape (300,)
# X_train shape (474, 80, 80, 3)
# y_train shape (474,)
# X_val shape (60, 80, 80, 3)
# y_val shape (60,)
# X_test shape (3, 80, 80, 3)
# y_test shape (3,)
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv_1 (Conv2D)             (None, 80, 80, 16)        1216
#
#  batch_normalization (Batch  (None, 80, 80, 16)        64
#  Normalization)
#
#  activation (Activation)     (None, 80, 80, 16)        0
#
#  dropout (Dropout)           (None, 80, 80, 16)        0
#
#  pool_1 (MaxPooling2D)       (None, 40, 40, 16)        0
#
#  conv_2 (Conv2D)             (None, 40, 40, 16)        6416
#
#  batch_normalization_1 (Bat  (None, 40, 40, 16)        64
#  chNormalization)
#
#  activation_1 (Activation)   (None, 40, 40, 16)        0
#
#  pool_2 (MaxPooling2D)       (None, 20, 20, 16)        0
#
#  dropout_1 (Dropout)         (None, 20, 20, 16)        0
#
#  flatten (Flatten)           (None, 6400)              0
#
#  fc_1 (Dense)                (None, 128)               819328
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  fc_2 (Dense)                (None, 64)                8256
#
#  batch_normalization_2 (Bat  (None, 64)                256
#  chNormalization)
#
#  activation_2 (Activation)   (None, 64)                0
#
#  fc_3 (Dense)                (None, 32)                2080
#
#  batch_normalization_3 (Bat  (None, 32)                128
#  chNormalization)
#
#  activation_3 (Activation)   (None, 32)                0
#
#  fc_4 (Dense)                (None, 1)                 33
#
# =================================================================
# Total params: 837841 (3.20 MB)
# Trainable params: 837585 (3.20 MB)
# Non-trainable params: 256 (1.00 KB)
# _________________________________________________________________
# /home/data/manual_annotate/test80/NonDrowsy
# /home/data/manual_annotate/test80/Drowsy
# 4/4 [==============================] - 0s 10ms/step - loss: 0.6930 - accuracy: 0.5000
#
# ----------Baseline Model Test Results----------
#
# Baseline Test Acc. 50.00%
# -----------------------------------------------
# Epoch 1/40
# 15/15 [==============================] - 5s 33ms/step - loss: 0.7637 - accuracy: 0.5359 - val_loss: 0.6943 - val_accuracy: 0.4833
# Epoch 2/40
# 15/15 [==============================] - 0s 23ms/step - loss: 0.7790 - accuracy: 0.5295 - val_loss: 0.6957 - val_accuracy: 0.4833
# Epoch 3/40
# 15/15 [==============================] - 0s 21ms/step - loss: 0.7634 - accuracy: 0.5359 - val_loss: 0.6950 - val_accuracy: 0.4833
# Epoch 4/40
# 15/15 [==============================] - 0s 18ms/step - loss: 0.7068 - accuracy: 0.5949 - val_loss: 0.6945 - val_accuracy: 0.4833
# Epoch 5/40
# 15/15 [==============================] - 0s 19ms/step - loss: 0.7222 - accuracy: 0.5928 - val_loss: 0.6911 - val_accuracy: 0.4833
# Epoch 6/40
# 15/15 [==============================] - 0s 21ms/step - loss: 0.7038 - accuracy: 0.6203 - val_loss: 0.6887 - val_accuracy: 0.4833
# Epoch 7/40
# 15/15 [==============================] - 0s 16ms/step - loss: 0.6694 - accuracy: 0.5970 - val_loss: 0.6875 - val_accuracy: 0.4833
# Epoch 8/40
# 15/15 [==============================] - 0s 16ms/step - loss: 0.6850 - accuracy: 0.6519 - val_loss: 0.6870 - val_accuracy: 0.4833
# Epoch 9/40
# 15/15 [==============================] - 0s 16ms/step - loss: 0.6811 - accuracy: 0.6519 - val_loss: 0.6858 - val_accuracy: 0.4833
# Epoch 10/40
# 15/15 [==============================] - 0s 15ms/step - loss: 0.6549 - accuracy: 0.6857 - val_loss: 0.6847 - val_accuracy: 0.4833
# Epoch 11/40
# 15/15 [==============================] - 0s 14ms/step - loss: 0.6207 - accuracy: 0.7004 - val_loss: 0.6837 - val_accuracy: 0.4833
# Epoch 12/40
# 15/15 [==============================] - 0s 16ms/step - loss: 0.6102 - accuracy: 0.6941 - val_loss: 0.6807 - val_accuracy: 0.4833
# Epoch 13/40
# 15/15 [==============================] - 0s 15ms/step - loss: 0.5811 - accuracy: 0.7363 - val_loss: 0.6776 - val_accuracy: 0.4833
# Epoch 14/40
# 15/15 [==============================] - 0s 17ms/step - loss: 0.5785 - accuracy: 0.7342 - val_loss: 0.6758 - val_accuracy: 0.4833
# Epoch 15/40
# 15/15 [==============================] - 0s 16ms/step - loss: 0.5446 - accuracy: 0.7468 - val_loss: 0.6704 - val_accuracy: 0.4833
# Epoch 16/40
# 15/15 [==============================] - 0s 15ms/step - loss: 0.5517 - accuracy: 0.7363 - val_loss: 0.6641 - val_accuracy: 0.4833
# Epoch 17/40
# 15/15 [==============================] - 0s 17ms/step - loss: 0.5142 - accuracy: 0.7743 - val_loss: 0.6530 - val_accuracy: 0.4833
# Epoch 18/40
# 15/15 [==============================] - 0s 17ms/step - loss: 0.4964 - accuracy: 0.8017 - val_loss: 0.6445 - val_accuracy: 0.4833
# Epoch 19/40
# 15/15 [==============================] - 0s 16ms/step - loss: 0.4946 - accuracy: 0.7975 - val_loss: 0.6439 - val_accuracy: 0.4833
# Epoch 20/40
# 15/15 [==============================] - 0s 15ms/step - loss: 0.4690 - accuracy: 0.8017 - val_loss: 0.6331 - val_accuracy: 0.5000
# Epoch 21/40
# 15/15 [==============================] - 0s 16ms/step - loss: 0.4740 - accuracy: 0.8080 - val_loss: 0.6230 - val_accuracy: 0.5000
# Epoch 22/40
# 15/15 [==============================] - 0s 17ms/step - loss: 0.4497 - accuracy: 0.8059 - val_loss: 0.6099 - val_accuracy: 0.5333
# Epoch 23/40
# 15/15 [==============================] - 0s 15ms/step - loss: 0.4339 - accuracy: 0.8270 - val_loss: 0.5840 - val_accuracy: 0.5500
# Epoch 24/40
# 15/15 [==============================] - 0s 16ms/step - loss: 0.4234 - accuracy: 0.8418 - val_loss: 0.5586 - val_accuracy: 0.5667
# Epoch 25/40
# 15/15 [==============================] - 0s 16ms/step - loss: 0.4349 - accuracy: 0.8080 - val_loss: 0.5353 - val_accuracy: 0.6500
# Epoch 26/40
# 15/15 [==============================] - 0s 15ms/step - loss: 0.3992 - accuracy: 0.8671 - val_loss: 0.5170 - val_accuracy: 0.6500
# Epoch 27/40
# 15/15 [==============================] - 0s 16ms/step - loss: 0.3578 - accuracy: 0.8861 - val_loss: 0.4994 - val_accuracy: 0.6333
# Epoch 28/40
# 15/15 [==============================] - 0s 15ms/step - loss: 0.3672 - accuracy: 0.8861 - val_loss: 0.4743 - val_accuracy: 0.7167
# Epoch 29/40
# 15/15 [==============================] - 0s 16ms/step - loss: 0.3329 - accuracy: 0.8966 - val_loss: 0.4668 - val_accuracy: 0.7000
# Epoch 30/40
# 15/15 [==============================] - 0s 15ms/step - loss: 0.3295 - accuracy: 0.8903 - val_loss: 0.4347 - val_accuracy: 0.8333
# Epoch 31/40
# 15/15 [==============================] - 0s 16ms/step - loss: 0.3246 - accuracy: 0.8903 - val_loss: 0.3981 - val_accuracy: 0.8500
# Epoch 32/40
# 15/15 [==============================] - 0s 15ms/step - loss: 0.3306 - accuracy: 0.8882 - val_loss: 0.3856 - val_accuracy: 0.8667
# Epoch 33/40
# 15/15 [==============================] - 0s 17ms/step - loss: 0.2868 - accuracy: 0.9114 - val_loss: 0.3762 - val_accuracy: 0.8667
# Epoch 34/40
# 15/15 [==============================] - 0s 15ms/step - loss: 0.2779 - accuracy: 0.9219 - val_loss: 0.3589 - val_accuracy: 0.8667
# Epoch 35/40
# 15/15 [==============================] - 0s 16ms/step - loss: 0.2896 - accuracy: 0.8966 - val_loss: 0.3469 - val_accuracy: 0.9000
# Epoch 36/40
# 15/15 [==============================] - 0s 17ms/step - loss: 0.2733 - accuracy: 0.9241 - val_loss: 0.3288 - val_accuracy: 0.9000
# Epoch 37/40
# 15/15 [==============================] - 0s 16ms/step - loss: 0.2593 - accuracy: 0.9262 - val_loss: 0.3148 - val_accuracy: 0.9167
# Epoch 38/40
# 15/15 [==============================] - 0s 15ms/step - loss: 0.2586 - accuracy: 0.9262 - val_loss: 0.2780 - val_accuracy: 0.9667
# Epoch 39/40
# 15/15 [==============================] - 0s 16ms/step - loss: 0.2571 - accuracy: 0.9325 - val_loss: 0.2638 - val_accuracy: 0.9667
# Epoch 40/40
# 15/15 [==============================] - 0s 16ms/step - loss: 0.2647 - accuracy: 0.9219 - val_loss: 0.2460 - val_accuracy: 0.9833
# /home/data/manual_annotate/test80/NonDrowsy
# /home/data/manual_annotate/test80/Drowsy
# 4/4 [==============================] - 0s 10ms/step - loss: 0.6043 - accuracy: 0.6400
#
# ----------Model Test Accuracy Results----------
#
# Test Acc. 64.00%
# -----------------------------------------------
# 63.999998569488525

# %% [markdown]
# #### Challenge
# Despite achieving commendable levels of accuracy in both training and validation phases, the model exhibited suboptimal performance in the testing phase, as evidenced by lower test accuracy. In an effort to ameliorate this discrepancy, a series of methodical adjustments were implemented: augmenting the model architecture with additional convolutional layers, expanding the model complexity by introducing more dense layers, varying the number of filters within convolutional layers, fine-tuning the learning rate, and altering the number of training epochs. Nonetheless, these modifications failed to yield a significant improvement in the model's ability to generalize effectively to the test images.
#
# Consequently, we shifted our focus to specifically analyzing the eye region, rather than the entire face, for drowsiness detection. To facilitate this approach, we employed external libraries, namely 'face_recognition' and 'dlib', to precisely extract the eye regions from our annotated image dataset. These cropped eye images were then utilized for the training, validation, and testing phases of our model.

# %% [markdown]
# #### Eye Images File Count

# %%
# Not sure if these folder precreated, recreating for GCP usage:

# !rm -rf /home/data/cropped_1/Drowsy
# !rm -rf /home/data/cropped_1/NonDrowsy
# !rm -rf /home/data/test_cropped_1/Drowsy
# !rm -rf /home/data/test_cropped_1/NonDrowsy

# !mkdir -p /home/data/cropped_1/Drowsy
# !mkdir -p /home/data/cropped_1/NonDrowsy/
# !mkdir -p /home/data/test_cropped_1/Drowsy/
# !mkdir -p /home/data/test_cropped_1/NonDrowsy/

# %%
# eye_train_drowsy = get_file_count('./data/cropped_1/Drowsy')
# eye_train_nondrowsy = get_file_count('./data/cropped_1/NonDrowsy')
# eye_test_drowsy = get_file_count('./data/test_cropped_1/Drowsy')
# eye_test_nondrowsy = get_file_count('./data/test_cropped_1/NonDrowsy')

eye_train_drowsy = get_file_count('/home/data/cropped_1/Drowsy')
eye_train_nondrowsy = get_file_count('/home/data/cropped_1/NonDrowsy')
eye_test_drowsy = get_file_count('/home/data/test_cropped_1/Drowsy')
eye_test_nondrowsy = get_file_count('/home/data/test_cropped_1/NonDrowsy')

eye_drowsy_count = eye_test_drowsy + eye_train_drowsy
eye_nondrowsy_count = eye_test_nondrowsy + eye_train_nondrowsy


# Create a dataframe
df = pd.DataFrame({'Category': ['Drowsy', 'Non Drowsy'], 'Count': [eye_drowsy_count, eye_nondrowsy_count]})

# Display the dataframe
display(df)
# Out:
#      Category  Count
# 0      Drowsy      0
# 1  Non Drowsy      0

# %% [markdown]
# #### Drowsy Eye Images

# %%
# plot_images(directory = './data/cropped_1/Drowsy', title = 'Drowsy')

plot_images(directory = '/home/data/cropped_1/Drowsy', title = 'Drowsy')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-55-7f7bdc0be388> in <cell line: 3>()
#       1 # plot_images(directory = './data/cropped_1/Drowsy', title = 'Drowsy')
#       2
# ----> 3 plot_images(directory = '/home/data/cropped_1/Drowsy', title = 'Drowsy')
#
# <ipython-input-23-e4dfb1b9ab0f> in plot_images(directory, title)
#      10     for i in range(4):
#      11         # Get the image file path
# ---> 12         image_file = os.path.join(directory, image_files[i])
#      13
#      14         # Open the image using PIL
#
# IndexError: list index out of range

# %% [markdown]
# #### Non Drowsy Eye Images

# %%
# plot_images(directory = './data/cropped_1/NonDrowsy', title = 'Non Drowsy')

plot_images(directory = '/home/data/cropped_1/NonDrowsy', title = 'Non Drowsy')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-56-432a01788a83> in <cell line: 3>()
#       1 # plot_images(directory = './data/cropped_1/NonDrowsy', title = 'Non Drowsy')
#       2
# ----> 3 plot_images(directory = '/home/data/cropped_1/NonDrowsy', title = 'Non Drowsy')
#
# <ipython-input-23-e4dfb1b9ab0f> in plot_images(directory, title)
#      10     for i in range(4):
#      11         # Get the image file path
# ---> 12         image_file = os.path.join(directory, image_files[i])
#      13
#      14         # Open the image using PIL
#
# IndexError: list index out of range

# %%
test_accuracy = []
models = []

for _ in range(10):
    # model, test_acc = preprocess_build_train_test('./data/cropped_1',
    #                                     './data/test_cropped_1', normalize=True, learning_rate=0.0001, epochs=40)

    model, test_acc = preprocess_build_train_test('/home/data/cropped_1',
                                         '/home/data/test_cropped_1', normalize=True, learning_rate=0.0001, epochs=40)
    test_accuracy.append(test_acc)
    models.append(model)

print(test_accuracy)

# %% [markdown]
# #### Display predictions

# %%
# KP: This portion, Mayank add individual sample image for adhoc test (not in gdrive)

# Preprocess the test images

image_test, label_test = data_preprocess_step1('/Users/mayank/Downloads/face2/face' + '/', num_images=5)
#image_test, label_test = data_preprocess_step1('./data/cropped_1' + '/', num_images=50)
shuffle = np.random.permutation(np.arange(image_test.shape[0]))
image_test, label_test = image_test[shuffle], label_test[shuffle]
image_test = tf.image.resize(image_test, size=(80,80))
image_test = image_test/255.0

# Make predictions using the trained model
pred_logits = models[0].predict(image_test)
probas = tf.sigmoid(pred_logits)
probas = probas.numpy().flatten()*100


# Create a figure to display the test images and their predictions
fig = plt.figure(figsize=(10, 50))

# Iterate over each test example
for j, example in enumerate(image_test):
    ax = fig.add_subplot(int(len(label_test)/4),4, j+1)
    ax.set_xticks([])
    ax.set_yticks([])
    ax.imshow(array_to_img(example))

    # Determine the ground truth label and the predicted probability of being drowsy
    if label_test[j]==0:
        label='Non Drowsy'
    else:
        label='Drowsy'

    # Display the ground truth label and the predicted probability
    ax.text(
        0.5, -0.15,
        'GT: {:s}\nPr(Drowsy)={:.0f}%'.format(label, probas[j]),
        size=10,
        color='black',
        horizontalalignment='center',
        verticalalignment='center',
        transform=ax.transAxes)

plt.tight_layout()
plt.show()

# %% [markdown]
# #### Filters Plot

# %%
def plot_filters(model, layer_num):

    # outputs of the first 4 layers, which include conv2D and max pooling layers
    layer_outputs = [layer.output for layer in model.layers[:layer_num]]
    activation_model = models.Model(inputs = model.input, outputs = layer_outputs)
    activations = activation_model.predict(img_tensor)

    # grab layer names
    layer_names = []
    for layer in model.layers[:layer_num]:
        layer_names.append(layer.name)

    # getting activations of each layer
    for idx, layer in enumerate(activations):
        if idx in (0,1):
            print('----------------')
            print('Geeting activations of layer',  idx+1, ':', layer_names[idx])
            activation = layer

            # shape of layer activation
            print('Images size is', activation.shape[1], 'x', activation.shape[2])
            print('Number of channels is', activation.shape[3])

            # print channels
            print('Printing channels:')

            # define nrows and ncols depending on number of channels
            if idx in (0,1):
                nrows, ncols = 8,4
            if idx in (2,3):
                nrows, ncols = 8,8

            # plots
            channel=0
            if idx in (0,1):
                f, axs = plt.subplots(nrows, ncols, figsize=(32,54))
            if idx in (2,3):
                f, axs = plt.subplots(nrows, ncols, figsize=(16,20))

            for i in range(nrows):
                for j in range(ncols):
                    if i==0 and j==0:
                        channel=0
                    else:
                        channel+=1

                    im = axs[i,j].matshow(activation[0,:, :, channel], cmap ='viridis')
                    axs[i,j].set(title=str(channel))
                    plt.colorbar(im, ax=axs[i, j], fraction=0.046, pad=0.04)
                    #axs[i,j].axis('off') # pay attention to the range of x and y axis

            plt.show()

img_tensor = np.expand_dims(image_test[2], axis = 0)
# Print image tensor shape
print('Shape of image:', img_tensor.shape)
# Print image
plt.imshow(img_tensor[0])
plt.title('label:' + str(label_test[2]))
plt.show()

plot_filters(models[2], 2)

# %%
img = load_img('./data/manual_annotate/test80/Drowsy/S0040.png', target_size=(80, 80))

# convert the image to an array using img_to_array
img_array = img_to_array(img)

print(img_array)

# %% [markdown]
# #### Additional Models Experimented

# %%
def build_modelV1():
    tf.keras.backend.clear_session()

    model = tf.keras.Sequential()

    # add first convolution layer to the model
    model.add(tf.keras.layers.Conv2D(
        filters=32,
        kernel_size=(5, 5),
        strides=(1, 1),
        padding='same',
        data_format='channels_last',
        name='conv_1',
        activation='relu'))


    # add a max pooling layer with pool size (2,2) and strides of 2
    # (this will reduce the spatial dimensions by half)
    model.add(tf.keras.layers.MaxPool2D(
        pool_size=(2, 2),
        name='pool_1'))


    # add second convolutional layer
    model.add(tf.keras.layers.Conv2D(
        filters=64,
        kernel_size=(5, 5),
        strides=(1, 1),
        padding='same',
        name='conv_2',
        activation='relu'))


    # add second max pooling layer with pool size (2,2) and strides of 2
    # (this will further reduce the spatial dimensions by half)
    model.add(tf.keras.layers.MaxPool2D(
        pool_size=(2, 2), name='pool_2')
    )


    # add a fully connected layer (need to flatten the output of the previous layers first)
    model.add(tf.keras.layers.Flatten())
    model.add(tf.keras.layers.Dense(
        units=1024,
        name='fc_1',
        activation='relu'))

    # add dropout layer
    model.add(tf.keras.layers.Dropout(
        rate=0.5))


    # add the last fully connected layer
    # this last layer sets the activation function to "None" in order to output the logits
    # note that passing activation = "sigmoid" will return class memembership probabilities but
    # in TensorFlow logits are prefered for numerical stability
    # set units=1 to get a single output unit (remember it's a binary classification problem)
    model.add(tf.keras.layers.Dense(
        units=1,
        name='fc_2',
        activation=None))

    # build model and print summary
    tf.random.set_seed(1)
    model.build(input_shape=(None, 80, 80, 3))


    return model

# %%
def build_modelV3():

    # Instantiate the model
    model = tf.keras.Sequential()

    # Adding first three convolutional layers
    model.add(tf.keras.layers.Conv2D(
                    filters = 32, # number of filters
                    kernel_size = (3,3), # height/width of filter
                    activation = 'relu', # activation function
                    input_shape = (80,80,3) # shape of input (image)
                    ))
    model.add(tf.keras.layers.Conv2D(
                    filters = 32, # number of filters
                    kernel_size = (3,3), # height/width of filter
                    activation = 'relu' # activation function
                    ))
    model.add(tf.keras.layers.Conv2D(
                    filters = 32, # number of filters
                    kernel_size = (3,3), # height/width of filter
                    activation = 'relu' # activation function
                    ))

    # Adding pooling after convolutional layers
    model.add(tf.keras.layers.MaxPooling2D(pool_size = (2,2))) # Dimensions of the region that you are pooling

    # Adding second set of convolutional layers
    model.add(tf.keras.layers.Conv2D(
                    filters = 32, # number of filters
                    kernel_size = (3,3), # height/width of filter
                    activation = 'relu' # activation function
                    ))
    model.add(tf.keras.layers.Conv2D(
                    filters = 32, # number of filters
                    kernel_size = (3,3), # height/width of filter
                    activation = 'relu' # activation function
                    ))

    # Add last pooling layer.
    model.add(tf.keras.layers.MaxPooling2D(pool_size=(2,2)))

    model.add(tf.keras.layers.Flatten())

    # Adding first dense layer with 256 nodes
    model.add(tf.keras.layers.Dense(256, activation='relu'))

    # Adding a dropout layer to avoid overfitting
    model.add(tf.keras.layers.Dropout(0.3))

    model.add(tf.keras.layers.Dense(128, activation='relu'))
    model.add(tf.keras.layers.Dropout(0.3))

    model.add(tf.keras.layers.Dense(64, activation='relu'))
    model.add(tf.keras.layers.Dropout(0.3))

    # adding output layer
    model.add(tf.keras.layers.Dense(1, activation = None))

        # build model and print summary
    tf.random.set_seed(1)
    model.build(input_shape=(None, 80, 80, 3))

    return model

# %% [markdown]
# #### Aditional utility function to predict images in a directory

# %%
from tensorflow import keras
import pandas as pd
from IPython.display import display, Image


def predict(model, img):
    img= keras.utils.load_img(
        img, target_size=(80, 80))
    img_array = keras.utils.img_to_array(img)
    img_array = tf.expand_dims(img_array, 0)  # Create batch axis
    predictions = model.predict(img_array)

    return predictions


dir_path = "./data/test_cropped/Drowsy/"
i = 0
file_path = []
prediction_results = []
for file_name in os.listdir(dir_path):

    predictions = predict(model, dir_path+file_name)

    print (predictions)

    # Convert logits to probabilities
    probabilities = tf.nn.sigmoid(predictions).numpy()

    prediction_results.append(probabilities[0])
    file_path.append(dir_path+file_name)



data = {'file_path': file_path, 'prediction_results': prediction_results}
df = pd.DataFrame(data)


'''
# Display the dataframe with filepath as a link to the image
for index, row in df.iterrows():
    display(Image(filename=row['file_path']))
    print(row)
'''



# Define the grid size based on the number of images
num_images = len(df)
grid_size = int(num_images ** 0.5) + 1

# Create a grid of subplots
fig, axs = plt.subplots(grid_size, grid_size, figsize=(12, 12))

# Iterate over the dataframe rows and display the image with prediction result
for index, row in df.iterrows():
    img = plt.imread(row['file_path'])
    ax = axs[index // grid_size, index % grid_size]
    ax.imshow(img)
    ax.axis('off')
    ax.set_title(f"Prediction: {row['prediction_results']:.2f}")

# Remove empty subplots
for i in range(num_images, grid_size ** 2):
    axs[i // grid_size, i % grid_size].axis('off')

plt.tight_layout()
plt.show()




print(np.array(prediction_results))
array = np.array(prediction_results)
print(np.size(array))

um_elements_greater_than_zero = np.sum(array > 0)

print (um_elements_greater_than_zero)

um_elements_less_than_zero = np.sum(array < 0)
print (um_elements_less_than_zero)
